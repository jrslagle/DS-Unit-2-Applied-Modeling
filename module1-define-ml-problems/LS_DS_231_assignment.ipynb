# %% [markdown]
# Lambda School Data Science
#
# *Unit 2, Sprint 3, Module 1*
#
# ---
#
#
# # Define ML problems
#
# You will use your portfolio project dataset for all assignments this sprint.
#
# ## Assignment
#
# Complete these tasks for your project, and document your decisions.
#
# - [ ] Choose your target. Which column in your tabular dataset will you predict?
# - [ ] Is your problem regression or classification?
# - [ ] How is your target distributed?
#     - Classification: How many classes? Are the classes imbalanced?
#     - Regression: Is the target right-skewed? If so, you may want to log transform the target.
# - [ ] Choose your evaluation metric(s).
#     - Classification: Is your majority class frequency >= 50% and < 70% ? If so, you can just use accuracy if you want. Outside that range, accuracy could be misleading. What evaluation metric will you choose, in addition to or instead of accuracy?
#     - Regression: Will you use mean absolute error, root mean squared error, R^2, or other regression metrics?
# - [ ] Choose which observations you will use to train, validate, and test your model.
#     - Are some observations outliers? Will you exclude them?
#     - Will you do a random split or a time-based split?
# - [ ] Begin to clean and explore your data.
# - [ ] Begin to choose which features, if any, to exclude. Would some features "leak" future information?
#
# If you haven't found a dataset yet, do that today. [Review requirements for your portfolio project](https://lambdaschool.github.io/ds/unit2) and choose your dataset.
#
# Some students worry, ***what if my model isn't “good”?*** Then, [produce a detailed tribute to your wrongness. That is science!](https://twitter.com/nathanwpyle/status/1176860147223867393)

# %% [markdown]
# ## City-Data.com ##

# %%
# use Washington County, UT as an example
url = 'http://www.city-data.com/county/Washington_County-UT.html'
html = !curl {wash_county_url}
print(html[:5])
# Out:
# ['<!DOCTYPE html>', '<html lang="en">', ' <head>', ' <meta charset="utf-8"/>', '<meta http-equiv="Content-Language" content="en"/>']

# %%
# Suicides per 1,000,000 population from 2000 to 2006: 150.4


# To extract a list of column names from a website describing a dataset
import re
# html = !curl https://archive.ics.uci.edu/ml/datasets/Congressional+Voting+Records
# matches = [ re.search('\. ([\w -]+): 2', line) for line in html ]

matches = [ re.search('Suicides per ([\d,]+) population from (\d{4}) to (\d{4}):', line) for line in html ]
column_names = [ match.group(0) for match in matches if match ]
print(len(column_names), column_names)
# Out:
# 1 ['Suicides per 1,000,000 population from 2000 to 2006:']

# %%
import re

for line in html:
  match = re.search('Suicides per ([\d,]+) population from (\d{4}) to (\d{4}): </b>([\d.]+)<b>', line)
  if match:
    print(html[i])
    a = match.group(1)
    print(int(a.replace(',', '')))
    print(int(match.group(2)))
    print(int(match.group(3)))
    print(float(match.group(4)))
# Out:
# I found a match!
# <b>Suicides per 1,000,000 population from 2000 to 2006: </b>150.4<b>. This is more than state average.</b><br/>
# Suicides per 1,000,000 population from 2000 to 2006: </b>150.4<b>
# 1000000
# 2000
# 2006
# 150.4

# %% [markdown]
# ## Data.gov ##

# %%
base_url = 'http://catalog.data.gov/api/3/'

# %%
# !wget http://demo.ckan.org/api/3/action/package_list
# Out:
# --2020-12-06 04:31:15--  http://demo.ckan.org/api/3/action/package_list
# Resolving demo.ckan.org (demo.ckan.org)... 172.67.170.152, 104.24.114.210, 104.24.115.210, ...
# Connecting to demo.ckan.org (demo.ckan.org)|172.67.170.152|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://demo.ckan.org/api/3/action/package_list [following]
# --2020-12-06 04:31:16--  https://demo.ckan.org/api/3/action/package_list
# Connecting to demo.ckan.org (demo.ckan.org)|172.67.170.152|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 188392 (184K) [application/json]
# Saving to: ‘package_list’
#
# package_list        100%[===================>] 183.98K  --.-KB/s    in 0.06s
#
# 2020-12-06 04:31:16 (2.86 MB/s) - ‘package_list’ saved [188392/188392]

# %%
import json
import os.path

# Only queries the website once
# base_url = 'http://demo.ckan.org/api/3/action/'
base_url = 'http://catalog.data.gov/api/3/action/'
query = 'package_search?q=suicide'
if not os.path.exists(query):
  query_url = base_url + query
  # !wget {query_url}

with open (query, "r") as myfile:
  data = myfile.read()
  data = json.loads(data)
data
# Out:
# URL transformed to HTTPS due to an HSTS policy
# --2020-12-06 05:21:18--  https://catalog.data.gov/api/3/action/package_search?q=suicide
# Resolving catalog.data.gov (catalog.data.gov)... 13.32.240.71, 13.32.240.94, 13.32.240.14, ...
# Connecting to catalog.data.gov (catalog.data.gov)|13.32.240.71|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68465 (67K) [application/json]
# Saving to: ‘package_search?q=suicide’
#
# package_search?q=su 100%[===================>]  66.86K   411KB/s    in 0.2s
#
# 2020-12-06 05:21:19 (411 KB/s) - ‘package_search?q=suicide’ saved [68465/68465]
# {'help': 'https://catalog.data.gov/api/3/action/help_show?name=package_search&host=&protocol=',
#  'result': {'count': 86,
#   'facets': {},
#   'results': [{'author': None,
#     'author_email': None,
#     'creator_user_id': '47303a9e-1187-4290-85a3-1fc02dc49e4a',
#     'extras': [{'key': 'publisher',
#       'value': 'National Transportation Safety Board'},
#      {'key': 'identifier', 'value': '{710F6EAC-E30A-4C49-A51D-BEAF25B54F87}'},
#      {'key': 'catalog_describedBy',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.json'},
#      {'key': 'harvest_source_id',
#       'value': '68151113-c0fb-4354-96f6-34376f841a1b'},
#      {'key': 'catalog_@context',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.jsonld'},
#      {'key': 'resource-type', 'value': 'Dataset'},
#      {'key': 'temporal', 'value': '1995-01-01T00:00:00Z/2014-12-31T23:59:59Z'},
#      {'key': '__category_tag_3b4e71c5-3c3c-43af-a3ff-81694225e453',
#       'value': '["Transportation"]'},
#      {'key': 'modified', 'value': '1995-01-01'},
#      {'key': 'harvest_source_title', 'value': 'NTSB json'},
#      {'key': 'source_schema_version', 'value': '1.1'},
#      {'key': 'source_datajson_identifier', 'value': True},
#      {'key': 'programCode', 'value': ['000:000']},
#      {'key': 'bureauCode', 'value': ['424:00']},
#      {'key': 'accrualPeriodicity', 'value': 'irregular'},
#      {'key': 'catalog_conformsTo',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema'},
#      {'key': 'accessLevel', 'value': 'public'},
#      {'key': 'harvest_object_id',
#       'value': 'bee8327e-82c1-4ab4-bdc1-e49d08987822'},
#      {'key': 'source_hash',
#       'value': '85123eeac8bb6c41a94629c208fe9aa6832f051c'},
#      {'key': 'harvest_object_id',
#       'value': 'bee8327e-82c1-4ab4-bdc1-e49d08987822'},
#      {'key': 'harvest_source_id',
#       'value': '68151113-c0fb-4354-96f6-34376f841a1b'},
#      {'key': 'harvest_source_title', 'value': 'NTSB json'}],
#     'groups': [{'description': '',
#       'display_name': 'Consumer',
#       'id': '3b4e71c5-3c3c-43af-a3ff-81694225e453',
#       'image_display_url': '',
#       'name': 'consumer9350',
#       'title': 'Consumer'}],
#     'id': 'd5564e37-15d2-4cd9-a64e-14a8f192022d',
#     'isopen': False,
#     'license_id': 'notspecified',
#     'license_title': 'License not specified',
#     'maintainer': 'Rahiq Syed',
#     'maintainer_email': 'rahiq.syed@ntsb.gov',
#     'metadata_created': '2015-12-16T18:13:33.887486',
#     'metadata_modified': '2015-12-17T15:24:59.627155',
#     'name': 'air-carrier-occurrences-involving-illegal-acts-sabotage-suicide-or-terrorism-1995-through-',
#     'notes': 'Air Carrier Occurrences Involving Illegal Acts (Sabotage, Suicide, or Terrorism), 1995 through 2014',
#     'num_resources': 1,
#     'num_tags': 14,
#     'organization': {'approval_status': 'approved',
#      'created': '2013-05-18T11:43:34.663825',
#      'description': '',
#      'id': '620f9a8a-96e7-4430-b31f-50fafba1b0ab',
#      'image_url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/16/Seal_of_the_United_States_National_Transportation_Safety_Board.svg/1200px-Seal_of_the_United_States_National_Transportation_Safety_Board.svg.png',
#      'is_organization': True,
#      'name': 'ntsb-gov',
#      'revision_id': '4cb0f554-9ff9-4f70-8d9d-73e7650b74d6',
#      'state': 'active',
#      'title': 'National Transportation Safety Board',
#      'type': 'organization'},
#     'owner_org': '620f9a8a-96e7-4430-b31f-50fafba1b0ab',
#     'private': False,
#     'relationships_as_object': [],
#     'relationships_as_subject': [],
#     'resources': [{'archiver': '{\'is_broken_printable\': \'Not sure if broken\', \'updated\': \'2017-12-09T03:58:43.725998\', \'cache_filepath\': None, \'last_success\': None, \'size\': u\'0\', \'is_broken\': None, \'failure_count\': 2, \'etag\': None, \'status\': \'Download failure\', \'url_redirected_to\': None, \'hash\': None, \'status_id\': 22, \'reason\': u"\'SSLError\' object has no attribute \'reason\'", \'last_modified\': None, \'resource_timestamp\': \'2015-12-17T15:24:59.627155\', \'mimetype\': None, \'cache_url\': None, \'created\': \'2017-12-09T03:58:44.227993\', \'first_failure\': \'2017-12-09T03:58:44.219007\'}',
#       'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2015-12-16T13:13:34.408619',
#       'description': 'table12_2014.csv',
#       'format': 'CSV',
#       'hash': '',
#       'id': '4589d235-faa2-48d5-9c93-c9159510f73b',
#       'last_modified': None,
#       'mimetype': 'text/csv',
#       'mimetype_inner': None,
#       'name': 'Comma Separated Values File',
#       'no_real_name': 'True',
#       'package_id': 'd5564e37-15d2-4cd9-a64e-14a8f192022d',
#       'position': 0,
#       'qa': '{\'updated\': \'2017-12-09T06:48:38.538481\', \'openness_score\': 3, \'archival_timestamp\': \'2017-12-09T03:58:43.725998\', \'format\': u\'CSV\', \'created\': \'2017-12-09T06:48:45.638332\', \'resource_timestamp\': None, \'openness_score_reason\': u\'URL extension "csv" relates to format "CSV" and receives score: 3.\'}',
#       'resource_type': None,
#       'revision_id': 'a01cfa78-aac7-4126-baea-c148ce69c493',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 9, 'total': 503},
#       'url': 'http://www.ntsb.gov/investigations/data/Documents/datafiles/table12_2014.csv',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None}],
#     'revision_id': 'bea8e643-682e-4899-b4ac-87a378ac14a6',
#     'state': 'active',
#     'tags': [{'display_name': 'air-carrier',
#       'id': '1be16150-6304-4e84-8bc9-35471aa62647',
#       'name': 'air-carrier',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'airlines',
#       'id': '16b1db58-ff6f-4f9d-967d-8bd9193f758c',
#       'name': 'airlines',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'aviation',
#       'id': 'f4f1b6be-83c1-463e-bfda-5556e15ff6f2',
#       'name': 'aviation',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'aviation-accident',
#       'id': 'b3590552-7df5-4419-8c5e-b1ae22bbec22',
#       'name': 'aviation-accident',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'civil-aviation',
#       'id': 'f0656825-8c13-4cc1-be9b-ed71a9481f46',
#       'name': 'civil-aviation',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'destroyed-aircraft',
#       'id': 'c389f581-19b7-44ce-9586-5edad2452dcd',
#       'name': 'destroyed-aircraft',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'fatal-accidents',
#       'id': '8ed31667-00eb-43b2-ad38-348d240e75a9',
#       'name': 'fatal-accidents',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'fatalities',
#       'id': 'abcfb4fd-5aa0-4484-a245-e1b399ecf0e8',
#       'name': 'fatalities',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'hazardous-materials',
#       'id': '558edb35-a410-468e-8f43-b89d19863f19',
#       'name': 'hazardous-materials',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'highway',
#       'id': '25c03e57-ac97-43ad-9201-e2142d927663',
#       'name': 'highway',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'marine',
#       'id': 'f2ee2106-f44e-4421-ac64-6ed0f2451d6c',
#       'name': 'marine',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'passenger-injuries',
#       'id': '0d408efe-0b1f-4ca7-8c70-281dc3168b69',
#       'name': 'passenger-injuries',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'pipeline',
#       'id': 'ead71661-9dab-498a-9537-294710a918c6',
#       'name': 'pipeline',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'safety',
#       'id': 'ce015bbe-e863-495f-bd99-a9837e240898',
#       'name': 'safety',
#       'state': 'active',
#       'vocabulary_id': None}],
#     'title': 'Air Carrier Occurrences Involving Illegal Acts (Sabotage, Suicide, or Terrorism), 1995 through 2014',
#     'tracking_summary': {'recent': 14, 'total': 1061},
#     'type': 'dataset',
#     'url': None,
#     'version': None},
#    {'author': None,
#     'author_email': None,
#     'creator_user_id': '47303a9e-1187-4290-85a3-1fc02dc49e4a',
#     'extras': [{'key': 'publisher', 'value': 'data.wa.gov'},
#      {'key': 'accessLevel', 'value': 'public'},
#      {'key': 'catalog_describedBy',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.json'},
#      {'key': 'harvest_source_id',
#       'value': 'd005e5c4-7890-4550-8088-388b91267384'},
#      {'key': 'catalog_@context',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.jsonld'},
#      {'key': 'issued', 'value': '2016-01-20'},
#      {'key': 'resource-type', 'value': 'Dataset'},
#      {'key': 'modified', 'value': '2016-01-20'},
#      {'key': 'harvest_source_title', 'value': 'WA JSON'},
#      {'key': 'source_schema_version', 'value': '1.1'},
#      {'key': 'source_datajson_identifier', 'value': True},
#      {'key': 'identifier', 'value': 'https://data.wa.gov/api/views/k96r-7t2r'},
#      {'key': 'catalog_@id', 'value': 'https://data.wa.gov/data.json'},
#      {'key': 'catalog_conformsTo',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema'},
#      {'key': 'landingPage', 'value': 'https://data.wa.gov/d/k96r-7t2r'},
#      {'key': 'harvest_object_id',
#       'value': '6cf58dfc-c532-4d4b-a597-04dbb0fb6307'},
#      {'key': 'source_hash',
#       'value': 'f888ba0b8ba76bf5b331d757d7766a44cb950e0c'},
#      {'key': 'harvest_object_id',
#       'value': '6cf58dfc-c532-4d4b-a597-04dbb0fb6307'},
#      {'key': 'harvest_source_id',
#       'value': 'd005e5c4-7890-4550-8088-388b91267384'},
#      {'key': 'harvest_source_title', 'value': 'WA JSON'}],
#     'groups': [{'description': 'Local Government Topic - for all datasets with state, local, county organizations',
#       'display_name': 'Local Government',
#       'id': 'ccc6c266-eee8-44bd-89aa-7cd8c4c6bf46',
#       'image_display_url': '',
#       'name': 'local',
#       'title': 'Local Government'}],
#     'id': '19bca9aa-ef8a-4287-8521-2059fa08db3b',
#     'isopen': False,
#     'license_id': 'notspecified',
#     'license_title': 'License not specified',
#     'maintainer': 'Alysa Kipersztok',
#     'maintainer_email': None,
#     'metadata_created': '2016-01-28T05:23:33.375048',
#     'metadata_modified': '2018-02-03T22:48:11.848988',
#     'name': 'youth-suicide-deaths-in-washington-state-by-gender-age-0-17-years-from-2008-2012',
#     'notes': 'Youth Suicide Deaths in Washington State by Gender Age 0-17 Years, from 2008-2012',
#     'num_resources': 4,
#     'num_tags': 0,
#     'organization': {'approval_status': 'approved',
#      'created': '2014-04-16T13:42:21.348635',
#      'description': '',
#      'id': '1bbe7404-4388-4132-84af-58a6801cb190',
#      'image_url': '',
#      'is_organization': True,
#      'name': 'state-of-washington',
#      'revision_id': '76568c20-32f1-4ff6-838e-f27f054d7b64',
#      'state': 'active',
#      'title': 'State of Washington',
#      'type': 'organization'},
#     'owner_org': '1bbe7404-4388-4132-84af-58a6801cb190',
#     'private': False,
#     'relationships_as_object': [],
#     'relationships_as_subject': [],
#     'resources': [{'archiver': '{\'is_broken_printable\': \'Downloaded OK\', \'updated\': \'2017-11-08T13:05:03.790139\', \'cache_filepath\': u\'None\', \'last_success\': \'2017-11-08T13:05:03.790139\', \'size\': u\'3\', \'is_broken\': False, \'failure_count\': 0, \'etag\': u\'W/"ca27211ac09c953e2364f90594218804"\', \'status\': \'Archived successfully\', \'url_redirected_to\': None, \'hash\': u\'None\', \'status_id\': 0, \'reason\': u\'\', \'last_modified\': u\'Wed, 20 Jan 2016 04:26:11 UTC\', \'resource_timestamp\': \'2016-03-10T05:39:47.955305\', \'mimetype\': u\'text/csv\', \'cache_url\': u\'None\', \'created\': \'2017-11-08T13:05:03.799569\', \'first_failure\': None}',
#       'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2016-01-28T00:23:33.492219',
#       'description': '',
#       'format': 'CSV',
#       'hash': '',
#       'id': 'c752b4ee-96b0-4885-acea-0467dc51fe20',
#       'last_modified': None,
#       'mimetype': 'text/csv',
#       'mimetype_inner': None,
#       'name': 'Comma Separated Values File',
#       'no_real_name': 'True',
#       'package_id': '19bca9aa-ef8a-4287-8521-2059fa08db3b',
#       'position': 0,
#       'qa': '{\'updated\': \'2017-11-10T05:25:25.128125\', \'openness_score\': 3, \'archival_timestamp\': \'2017-11-08T13:05:03.790139\', \'format\': u\'CSV\', \'created\': \'2017-11-10T05:25:25.131797\', \'resource_timestamp\': None, \'openness_score_reason\': u\'URL extension "csv" relates to format "CSV" and receives score: 3.\'}',
#       'resource_type': None,
#       'revision_id': '613a4e92-9d20-488f-9eae-aea826855564',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 5, 'total': 164},
#       'url': 'https://data.wa.gov/api/views/k96r-7t2r/rows.csv?accessType=DOWNLOAD',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None},
#      {'archiver': '{\'is_broken_printable\': \'Downloaded OK\', \'updated\': \'2017-11-08T13:05:03.926805\', \'cache_filepath\': u\'None\', \'last_success\': \'2017-11-08T13:05:03.926805\', \'size\': u\'3\', \'is_broken\': False, \'failure_count\': 0, \'etag\': u\'W/"ca27211ac09c953e2364f90594218804"\', \'status\': \'Archived successfully\', \'url_redirected_to\': None, \'hash\': u\'None\', \'status_id\': 0, \'reason\': u\'\', \'last_modified\': u\'Wed, 20 Jan 2016 04:26:11 UTC\', \'resource_timestamp\': \'2016-06-16T06:23:06.734450\', \'mimetype\': u\'application/rdf+xml\', \'cache_url\': u\'None\', \'created\': \'2017-11-08T13:05:03.947484\', \'first_failure\': None}',
#       'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2016-01-28T00:23:33.492255',
#       'description': '',
#       'format': 'RDF',
#       'hash': '',
#       'id': '6ec7c931-d883-46a5-83b9-0b61f377ba21',
#       'last_modified': None,
#       'mimetype': 'application/rdf+xml',
#       'mimetype_inner': None,
#       'name': 'RDF File',
#       'no_real_name': 'True',
#       'package_id': '19bca9aa-ef8a-4287-8521-2059fa08db3b',
#       'position': 1,
#       'qa': '{\'updated\': \'2017-11-10T05:25:25.139654\', \'openness_score\': 5, \'archival_timestamp\': \'2017-11-08T13:05:03.926805\', \'format\': u\'RDF\', \'created\': \'2017-11-10T05:25:25.144432\', \'resource_timestamp\': None, \'openness_score_reason\': u\'URL extension "rdf" relates to format "RDF" and receives score: 5.\'}',
#       'resource_type': None,
#       'revision_id': '613a4e92-9d20-488f-9eae-aea826855564',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 2, 'total': 8},
#       'url': 'https://data.wa.gov/api/views/k96r-7t2r/rows.rdf?accessType=DOWNLOAD',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None},
#      {'archiver': '{\'is_broken_printable\': \'Downloaded OK\', \'updated\': \'2017-11-08T13:05:04.162518\', \'cache_filepath\': u\'None\', \'last_success\': \'2017-11-08T13:05:04.162518\', \'size\': u\'3\', \'is_broken\': False, \'failure_count\': 0, \'etag\': u\'W/"ca27211ac09c953e2364f90594218804"\', \'status\': \'Archived successfully\', \'url_redirected_to\': None, \'hash\': u\'None\', \'status_id\': 0, \'reason\': u\'\', \'last_modified\': u\'Wed, 20 Jan 2016 04:26:11 UTC\', \'resource_timestamp\': \'2016-06-16T06:23:06.734450\', \'mimetype\': u\'application/json\', \'cache_url\': u\'None\', \'created\': \'2017-11-08T13:05:04.171430\', \'first_failure\': None}',
#       'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2016-01-28T00:23:33.492265',
#       'description': '',
#       'format': 'JSON',
#       'hash': '',
#       'id': '9871d62f-0e26-4438-ba80-b210e51a4a84',
#       'last_modified': None,
#       'mimetype': 'application/json',
#       'mimetype_inner': None,
#       'name': 'JSON File',
#       'no_real_name': 'True',
#       'package_id': '19bca9aa-ef8a-4287-8521-2059fa08db3b',
#       'position': 2,
#       'qa': '{\'updated\': \'2017-11-10T05:25:25.151780\', \'openness_score\': 3, \'archival_timestamp\': \'2017-11-08T13:05:04.162518\', \'format\': u\'JSON\', \'created\': \'2017-11-10T05:25:25.155646\', \'resource_timestamp\': None, \'openness_score_reason\': u\'URL extension "json" relates to format "JSON" and receives score: 3.\'}',
#       'resource_type': None,
#       'revision_id': '613a4e92-9d20-488f-9eae-aea826855564',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 1, 'total': 6},
#       'url': 'https://data.wa.gov/api/views/k96r-7t2r/rows.json?accessType=DOWNLOAD',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None},
#      {'archiver': '{\'is_broken_printable\': \'Downloaded OK\', \'updated\': \'2017-11-08T13:05:04.343673\', \'cache_filepath\': u\'None\', \'last_success\': \'2017-11-08T13:05:04.343673\', \'size\': u\'3\', \'is_broken\': False, \'failure_count\': 0, \'etag\': u\'W/"ca27211ac09c953e2364f90594218804"\', \'status\': \'Archived successfully\', \'url_redirected_to\': None, \'hash\': u\'None\', \'status_id\': 0, \'reason\': u\'\', \'last_modified\': u\'Wed, 20 Jan 2016 04:26:11 UTC\', \'resource_timestamp\': \'2016-06-16T06:23:06.734450\', \'mimetype\': u\'text/xml\', \'cache_url\': u\'None\', \'created\': \'2017-11-08T13:05:04.353885\', \'first_failure\': None}',
#       'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2016-01-28T00:23:33.492307',
#       'description': '',
#       'format': 'XML',
#       'hash': '',
#       'id': '53597a97-0a7d-43f2-857f-998c4a85a44f',
#       'last_modified': None,
#       'mimetype': 'application/xml',
#       'mimetype_inner': None,
#       'name': 'XML File',
#       'no_real_name': 'True',
#       'package_id': '19bca9aa-ef8a-4287-8521-2059fa08db3b',
#       'position': 3,
#       'qa': '{\'updated\': \'2017-11-10T05:25:25.163867\', \'openness_score\': 3, \'archival_timestamp\': \'2017-11-08T13:05:04.343673\', \'format\': u\'XML\', \'created\': \'2017-11-10T05:25:25.167905\', \'resource_timestamp\': None, \'openness_score_reason\': u\'URL extension "xml" relates to format "XML" and receives score: 3.\'}',
#       'resource_type': None,
#       'revision_id': '613a4e92-9d20-488f-9eae-aea826855564',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 1, 'total': 14},
#       'url': 'https://data.wa.gov/api/views/k96r-7t2r/rows.xml?accessType=DOWNLOAD',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None}],
#     'revision_id': '613a4e92-9d20-488f-9eae-aea826855564',
#     'state': 'active',
#     'tags': [],
#     'title': 'Youth Suicide Deaths in Washington State by Gender Age 0-17 Years, from 2008-2012',
#     'tracking_summary': {'recent': 11, 'total': 376},
#     'type': 'dataset',
#     'url': None,
#     'version': None},
#    {'author': None,
#     'author_email': None,
#     'creator_user_id': '47303a9e-1187-4290-85a3-1fc02dc49e4a',
#     'extras': [{'key': 'postalCode', 'value': ''},
#      {'key': 'harvest_source_id',
#       'value': '5859cfed-553c-48de-a478-b67b5225f6fc'},
#      {'key': 'resource-type', 'value': 'Dataset'},
#      {'key': 'mission', 'value': ''},
#      {'key': 'expertise', 'value': ''},
#      {'key': 'repPhone', 'value': ''},
#      {'key': 'source_hash',
#       'value': 'e4968a11d1ec4bc9a914b415908d8d73eece5e98'},
#      {'key': 'sizeSqft', 'value': '0'},
#      {'key': 'catalog_conformsTo',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema'},
#      {'key': 'catalog_@context',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.jsonld'},
#      {'key': 'fax', 'value': ''},
#      {'key': 'catalog_describedBy',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.json'},
#      {'key': 'address1', 'value': ''},
#      {'key': 'address2', 'value': ''},
#      {'key': 'address3', 'value': ''},
#      {'key': 'harvest_source_title',
#       'value': 'Federal Laboratory Consortium Data.json'},
#      {'key': 'source_schema_version', 'value': '1.1'},
#      {'key': 'phone', 'value': ''},
#      {'key': 'accessLevel', 'value': 'public'},
#      {'key': 'harvest_object_id',
#       'value': '14d30042-2a75-4f99-bc54-5733f4e34efc'},
#      {'key': 'publisher', 'value': 'Federal Laboratory Consortium'},
#      {'key': 'ownerOperatorCode', 'value': ''},
#      {'key': 't2Website', 'value': ''},
#      {'key': 'source_datajson_identifier', 'value': True},
#      {'key': 'stateCode', 'value': ''},
#      {'key': 'identifier', 'value': '2EB8EFCD-F21B-4B51-BA46-858319DF0AD6'},
#      {'key': 'flcBusinessUrl',
#       'value': 'https://flcbusiness.federallabs.org/#/laboratory/5348'},
#      {'key': 'harvest_object_id',
#       'value': '14d30042-2a75-4f99-bc54-5733f4e34efc'},
#      {'key': 'harvest_source_id',
#       'value': '5859cfed-553c-48de-a478-b67b5225f6fc'},
#      {'key': 'harvest_source_title',
#       'value': 'Federal Laboratory Consortium Data.json'}],
#     'groups': [],
#     'id': '9f18d1b9-be75-4907-857f-bba1b3be0ae8',
#     'isopen': False,
#     'license_id': 'notspecified',
#     'license_title': 'License not specified',
#     'maintainer': ' ',
#     'maintainer_email': None,
#     'metadata_created': '2017-03-08T15:45:42.182598',
#     'metadata_modified': '2017-03-08T15:45:42.217008',
#     'name': 'the-experimental-therapeutics-and-pathophysiology-branch-etpb-28c0a',
#     'notes': '\nThe overarching goals of the current (ETPB) are: (1) to provide\nadministrative support for our Section (SNMD); (2) to maintain a\ncommon screening program for the Division of Intramural Research\nProgram (DIRP) studies on mood and anxiety disorders; and (3) to\nsupport clinical and research training. The Screening Program\n(01-M-0254) provides oversight, training, and quality control of\nadministration of a range of structured diagnostic and dimensional\nmeasures of psychopathology. Aside from extensive clinical\nmeasures, the major data components that are centralized in the\nprogram include: (1) CTDB-Clinical trials database; (2) BioBNK that\ncontains a diverse set of biologic measures; and (3) MAP-R (Mood\nand Anxiety Disorders Repository protocol) of neuroimaging data.\nThe clinical measures collected include comprehensive diagnostic\ninterviews including history of suicide attempts and ideation,\nstress/trauma, sleep problems, temperament, psychosis, medical\nconditions, as well as dimensional measures of the core features of\nmood and related disorders including positive and negative affect,\narousal/regulatory systems and cognitive function.',
#     'num_resources': 1,
#     'num_tags': 0,
#     'organization': {'approval_status': 'approved',
#      'created': '2015-10-13T18:12:21.453690',
#      'description': 'The Federal Laboratory Consortium for Technology Transfer (FLC) is the nationwide network of federal laboratories that provides the forum to develop strategies and opportunities for linking laboratory mission technologies and expertise with the marketplace.',
#      'id': 'e21b7304-5ac3-4f0a-9a0f-25a8a6ab04be',
#      'image_url': 'https://secure.federallabs.org/images/flc-header.jpg',
#      'is_organization': True,
#      'name': 'federal-laboratory-consortium',
#      'revision_id': 'd7189270-0164-45b0-a835-a49617d382ef',
#      'state': 'active',
#      'title': 'Federal Laboratory Consortium',
#      'type': 'organization'},
#     'owner_org': 'e21b7304-5ac3-4f0a-9a0f-25a8a6ab04be',
#     'private': False,
#     'relationships_as_object': [],
#     'relationships_as_subject': [],
#     'resources': [{'archiver': "{'is_broken_printable': 'Downloaded OK', 'updated': '2017-11-18T18:34:31.716102', 'cache_filepath': u'None', 'last_success': '2017-11-18T18:34:31.716102', 'size': u'3', 'is_broken': False, 'failure_count': 0, 'etag': None, 'status': 'Archived successfully', 'url_redirected_to': u'https://www.nimh.nih.gov/labs-at-nimh/research-areas/clinics-and-labs/etpb/facilities.shtml', 'hash': u'None', 'status_id': 0, 'reason': u'', 'last_modified': None, 'resource_timestamp': '2017-03-08T15:45:42.182598', 'mimetype': u'text/html', 'cache_url': u'None', 'created': '2017-11-18T18:34:31.732677', 'first_failure': None}",
#       'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2017-03-08T15:45:42.245223',
#       'description': '',
#       'format': 'HTML',
#       'hash': '',
#       'id': 'a83401e5-1e7c-4bbe-ae52-a57db0184f3d',
#       'last_modified': None,
#       'mimetype': '',
#       'mimetype_inner': None,
#       'name': 'Web Page',
#       'no_real_name': 'True',
#       'package_id': '9f18d1b9-be75-4907-857f-bba1b3be0ae8',
#       'position': 0,
#       'qa': '{\'updated\': \'2017-11-22T05:29:29.250363\', \'openness_score\': 0, \'archival_timestamp\': \'2017-11-18T18:34:31.716102\', \'format\': u\'HTML\', \'created\': \'2017-11-22T05:29:29.261754\', \'resource_timestamp\': None, \'openness_score_reason\': u\'URL extension "shtml" is an unknown format. Format field "HTML" receives score: 0.\'}',
#       'resource_type': None,
#       'revision_id': '5d932be3-66c1-484d-be3d-26e1ae750b40',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 4, 'total': 68},
#       'url': 'http://www.nimh.nih.gov/labs-at-nimh/research-areas/clinics-and-labs/etpb/facilities.shtml',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None}],
#     'revision_id': '5d932be3-66c1-484d-be3d-26e1ae750b40',
#     'state': 'active',
#     'tags': [],
#     'title': 'The Experimental Therapeutics and Pathophysiology Branch (ETPB)',
#     'tracking_summary': {'recent': 4, 'total': 80},
#     'type': 'dataset',
#     'url': None,
#     'version': None},
#    {'author': None,
#     'author_email': None,
#     'creator_user_id': '47303a9e-1187-4290-85a3-1fc02dc49e4a',
#     'extras': [{'key': 'postalCode', 'value': ''},
#      {'key': 'harvest_source_id',
#       'value': '5859cfed-553c-48de-a478-b67b5225f6fc'},
#      {'key': 'resource-type', 'value': 'Dataset'},
#      {'key': 'mission', 'value': ''},
#      {'key': 'expertise', 'value': ''},
#      {'key': 'repPhone', 'value': ''},
#      {'key': 'source_hash',
#       'value': 'e03c53a46b743094b76a49fcb8e053e410e5dc9d'},
#      {'key': 'sizeSqft', 'value': '0'},
#      {'key': 'catalog_conformsTo',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema'},
#      {'key': 'catalog_@context',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.jsonld'},
#      {'key': 'fax', 'value': ''},
#      {'key': 'catalog_describedBy',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.json'},
#      {'key': 'address1', 'value': ''},
#      {'key': 'address2', 'value': ''},
#      {'key': 'address3', 'value': ''},
#      {'key': 'harvest_source_title',
#       'value': 'Federal Laboratory Consortium Data.json'},
#      {'key': 'source_schema_version', 'value': '1.1'},
#      {'key': 'phone', 'value': ''},
#      {'key': 'accessLevel', 'value': 'public'},
#      {'key': 'harvest_object_id',
#       'value': '9f8a67b5-93f9-4065-ad38-a2d28691bf33'},
#      {'key': 'publisher', 'value': 'Federal Laboratory Consortium'},
#      {'key': 'ownerOperatorCode', 'value': ''},
#      {'key': 't2Website', 'value': ''},
#      {'key': 'source_datajson_identifier', 'value': True},
#      {'key': 'stateCode', 'value': ''},
#      {'key': 'identifier', 'value': '6C5220D7-C683-4637-A29B-85C32CBA5E39'},
#      {'key': 'flcBusinessUrl',
#       'value': 'https://flcbusiness.federallabs.org/#/laboratory/5349'},
#      {'key': 'harvest_object_id',
#       'value': '9f8a67b5-93f9-4065-ad38-a2d28691bf33'},
#      {'key': 'harvest_source_id',
#       'value': '5859cfed-553c-48de-a478-b67b5225f6fc'},
#      {'key': 'harvest_source_title',
#       'value': 'Federal Laboratory Consortium Data.json'}],
#     'groups': [],
#     'id': '519a4b7b-7ef4-483c-8024-5f7b200fb9ba',
#     'isopen': False,
#     'license_id': 'notspecified',
#     'license_title': 'License not specified',
#     'maintainer': ' ',
#     'maintainer_email': None,
#     'metadata_created': '2017-03-08T15:45:53.397691',
#     'metadata_modified': '2017-03-08T15:45:53.432674',
#     'name': 'section-on-the-neurobiology-and-treatment-of-mood-disorders-snmd-0bc63',
#     'notes': '\nThe major goal of the SNMD is to conduct therapeutic studies on\ntreatment-resistant depression, with a more recent extension to\npatients with suicidal ideation and behavior. The major focus of\nour clinical research is treatment-resistant depression.SNMD is housed in the Mood Disorders Research Unit, 7SE north of\nthe NIH Clinical Center, a state-of-the art facility which\ncurrently has 12 inpatient beds designated for patients with mood\ndisorders of which Dr. Zarate is the Unit Chief. Clinical staffing\nincludes a 24 hour, 365 day on-call psychiatrist, experienced nurse\nclinicians, etc. Our ability to study patients for long periods of\ntime, over nights and weekends in both the drug free as well as\npost-treatment states provides a unique opportunity for\ncomprehensive evaluation that would not be possible in the\nextramural world.The program attempts to identify reasons for and ameliorate the\nhigh failure rate in recent pharmacologic trials of mood disorders\nincluding patient heterogeneity, inadequate diagnostic and response\nbiomarkers, incorrect dose range, high placebo response rates,\ninadequate trial designs, patient and investigator expectation\nbiases, lack of target engagement, and a host of operational\nissues. By avoiding many of these situations, we can improve the\nfeasibility and acceptability by advancing early proof-of-concept\nclinical trials designs that can be subsequently translated to our\nextramural partners for larger effectiveness and efficacy\nstudies.In addition to collaborative efforts designed to cover the full\nrange of biologic pathways underlying mood disorders, we have\nfocused our research on treatment-resistant depression in two major\nresearch areas: (1) neuroimaging; and (2) biomarkers of mood\ndisorders and treatment response. The\n      NIMH DIRP Cores have also provided an\nideal source of expertise in our neuroimaging studies. Our research\nhas also benefited enormously from both the NIH Clinical Center\nfacilities and the DIRP CORE facilities (e.g., sMRI, fMRI, PET,\nPSG, MEG, MRS, etc).',
#     'num_resources': 1,
#     'num_tags': 0,
#     'organization': {'approval_status': 'approved',
#      'created': '2015-10-13T18:12:21.453690',
#      'description': 'The Federal Laboratory Consortium for Technology Transfer (FLC) is the nationwide network of federal laboratories that provides the forum to develop strategies and opportunities for linking laboratory mission technologies and expertise with the marketplace.',
#      'id': 'e21b7304-5ac3-4f0a-9a0f-25a8a6ab04be',
#      'image_url': 'https://secure.federallabs.org/images/flc-header.jpg',
#      'is_organization': True,
#      'name': 'federal-laboratory-consortium',
#      'revision_id': 'd7189270-0164-45b0-a835-a49617d382ef',
#      'state': 'active',
#      'title': 'Federal Laboratory Consortium',
#      'type': 'organization'},
#     'owner_org': 'e21b7304-5ac3-4f0a-9a0f-25a8a6ab04be',
#     'private': False,
#     'relationships_as_object': [],
#     'relationships_as_subject': [],
#     'resources': [{'archiver': "{'is_broken_printable': 'Downloaded OK', 'updated': '2017-11-15T20:37:50.494812', 'cache_filepath': u'None', 'last_success': '2017-11-15T20:37:50.494812', 'size': u'3', 'is_broken': False, 'failure_count': 0, 'etag': None, 'status': 'Archived successfully', 'url_redirected_to': u'https://www.nimh.nih.gov/labs-at-nimh/research-areas/clinics-and-labs/etpb/facilities.shtml', 'hash': u'None', 'status_id': 0, 'reason': u'', 'last_modified': None, 'resource_timestamp': '2017-03-08T15:45:53.397691', 'mimetype': u'text/html', 'cache_url': u'None', 'created': '2017-11-15T20:37:50.509264', 'first_failure': None}",
#       'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2017-03-08T15:45:53.464592',
#       'description': '',
#       'format': 'HTML',
#       'hash': '',
#       'id': '564e57c5-c51c-4691-8fa1-6986f015cd78',
#       'last_modified': None,
#       'mimetype': '',
#       'mimetype_inner': None,
#       'name': 'Web Page',
#       'no_real_name': 'True',
#       'package_id': '519a4b7b-7ef4-483c-8024-5f7b200fb9ba',
#       'position': 0,
#       'qa': '{\'updated\': \'2017-11-19T19:20:40.772366\', \'openness_score\': 0, \'archival_timestamp\': \'2017-11-15T20:37:50.494812\', \'format\': u\'HTML\', \'created\': \'2017-11-19T19:20:40.779099\', \'resource_timestamp\': None, \'openness_score_reason\': u\'URL extension "shtml" is an unknown format. Format field "HTML" receives score: 0.\'}',
#       'resource_type': None,
#       'revision_id': '41ce49e2-a971-41a9-a739-bacae684171f',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 4, 'total': 68},
#       'url': 'http://www.nimh.nih.gov/labs-at-nimh/research-areas/clinics-and-labs/etpb/facilities.shtml',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None}],
#     'revision_id': '41ce49e2-a971-41a9-a739-bacae684171f',
#     'state': 'active',
#     'tags': [],
#     'title': 'Section on the Neurobiology and Treatment of Mood Disorders (SNMD)',
#     'tracking_summary': {'recent': 3, 'total': 104},
#     'type': 'dataset',
#     'url': None,
#     'version': None},
#    {'author': None,
#     'author_email': None,
#     'creator_user_id': '47303a9e-1187-4290-85a3-1fc02dc49e4a',
#     'extras': [{'key': 'publisher',
#       'value': 'Centers for Disease Control and Prevention'},
#      {'key': 'identifier', 'value': '65fb33a0-129d-45b5-9e0b-2e6b20b60af4'},
#      {'key': 'harvest_source_id',
#       'value': '6ecff745-213b-4114-8230-3a6aed46a149'},
#      {'key': 'issued', 'value': '2011-01-01'},
#      {'key': 'resource-type', 'value': 'Dataset'},
#      {'key': 'modified', 'value': '2011-01-01'},
#      {'key': 'harvest_source_title', 'value': 'HHS CAS JSON'},
#      {'key': 'source_schema_version', 'value': '1.0'},
#      {'key': 'source_datajson_identifier', 'value': True},
#      {'key': 'dataQuality', 'value': True},
#      {'key': 'theme', 'value': ['Health Care Providers', 'Other', 'Safety']},
#      {'key': 'bureauCode', 'value': ['009:20']},
#      {'key': 'spatial', 'value': 'United States'},
#      {'key': 'programCode', 'value': ['009:000']},
#      {'key': 'landingPage', 'value': 'http://vetoviolence.cdc.gov'},
#      {'key': 'accessLevel', 'value': 'public'},
#      {'key': 'harvest_object_id',
#       'value': '2bff87a5-0f23-4e0f-80cc-d4e6475052f6'},
#      {'key': 'source_hash',
#       'value': 'b36d9c52d7e0ad7844c9803b83d77e8df01ec361'}],
#     'groups': [],
#     'id': 'd6ba3e47-f7b8-4bf9-86c2-e658e14d543e',
#     'isopen': False,
#     'license_id': 'notspecified',
#     'license_title': 'License not specified',
#     'maintainer': 'Veto Violence',
#     'maintainer_email': 'VetoViolence@cdc.gov',
#     'metadata_created': '2020-07-22T16:57:11.126845',
#     'metadata_modified': '2020-07-22T16:57:11.162857',
#     'name': 'veto-violence-violence-education-tools-online-408ea',
#     'notes': 'VetoViolence.cdc.gov has been developed by the Centers for Disease Control and Prevention (CDC) to provide grantees and partners with access to training and tools that focus on the primary prevention of violence. The portal includes free training, program planning resources, and an online application for the creation of success stories. ',
#     'num_resources': 3,
#     'num_tags': 10,
#     'organization': {'approval_status': 'approved',
#      'created': '2013-08-26T15:35:30.958442',
#      'description': '',
#      'id': '3609164c-4c49-4a44-9179-23163027dc0a',
#      'image_url': 'https://www.hhs.gov/sites/default/files/web/images/seal_blue_gold_hi_res.jpg',
#      'is_organization': True,
#      'name': 'hhs-gov',
#      'revision_id': '30233016-f437-4829-9707-0116a827a3fe',
#      'state': 'active',
#      'title': 'U.S. Department of Health & Human Services',
#      'type': 'organization'},
#     'owner_org': '3609164c-4c49-4a44-9179-23163027dc0a',
#     'private': False,
#     'relationships_as_object': [],
#     'relationships_as_subject': [],
#     'resources': [{'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2020-07-22T16:57:11.174605',
#       'description': '',
#       'format': 'HTML',
#       'hash': '',
#       'id': '0689e541-5dba-4706-b631-5aeaf748bf62',
#       'last_modified': None,
#       'mimetype': 'text/html',
#       'mimetype_inner': None,
#       'name': 'Web Page',
#       'no_real_name': 'True',
#       'package_id': 'd6ba3e47-f7b8-4bf9-86c2-e658e14d543e',
#       'position': 0,
#       'resource_type': None,
#       'revision_id': 'e483366f-9a0a-42ec-8bdb-d62fe34d9542',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 1, 'total': 13},
#       'url': 'http://vetoviolence.cdc.gov/',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None},
#      {'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2020-07-22T16:57:11.174624',
#       'description': 'education-courses.html',
#       'format': 'HTML',
#       'hash': '',
#       'id': 'f60496a8-afba-4d50-8ad4-9e0db83fdcac',
#       'last_modified': None,
#       'mimetype': 'text/html',
#       'mimetype_inner': None,
#       'name': 'Web Page',
#       'no_real_name': 'True',
#       'package_id': 'd6ba3e47-f7b8-4bf9-86c2-e658e14d543e',
#       'position': 1,
#       'resource_type': None,
#       'revision_id': 'e483366f-9a0a-42ec-8bdb-d62fe34d9542',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 1, 'total': 12},
#       'url': 'http://vetoviolence.cdc.gov/education-courses.html',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None},
#      {'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2020-07-22T16:57:11.174630',
#       'description': 'success-worksheet.html',
#       'format': 'HTML',
#       'hash': '',
#       'id': 'd49f2960-e966-422f-a0a3-bc54d0b45865',
#       'last_modified': None,
#       'mimetype': 'text/html',
#       'mimetype_inner': None,
#       'name': 'Web Page',
#       'no_real_name': 'True',
#       'package_id': 'd6ba3e47-f7b8-4bf9-86c2-e658e14d543e',
#       'position': 2,
#       'resource_type': None,
#       'revision_id': 'e483366f-9a0a-42ec-8bdb-d62fe34d9542',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 1, 'total': 10},
#       'url': 'http://vetoviolence.cdc.gov/success-worksheet.html',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None}],
#     'revision_id': 'e483366f-9a0a-42ec-8bdb-d62fe34d9542',
#     'state': 'active',
#     'tags': [{'display_name': 'child-maltreatment',
#       'id': 'd64e0bbf-faab-40a3-9798-7bde155c16dd',
#       'name': 'child-maltreatment',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'intimate-partner-violence',
#       'id': '74a59272-2820-4479-8e0c-1944ca6693a7',
#       'name': 'intimate-partner-violence',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'principles-of-prevention-pop',
#       'id': '15ecc20c-1158-438a-adc2-f4bc4112894e',
#       'name': 'principles-of-prevention-pop',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'public-health',
#       'id': '5c51e3d7-b234-4289-aa78-485f9e396ce3',
#       'name': 'public-health',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'sexual-assault',
#       'id': '9f97b647-bc00-4cbf-b430-ce2a707f33ca',
#       'name': 'sexual-assault',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'stories',
#       'id': '2d7e3622-bcc2-4763-9a1b-e2db90c5c9cf',
#       'name': 'stories',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'suicide',
#       'id': '03bc20e4-dfbc-4097-a43a-7469533d969f',
#       'name': 'suicide',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'training',
#       'id': '1e4181ad-8565-43f8-a067-48294f5adf32',
#       'name': 'training',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'violence-prevention',
#       'id': '58c77389-43bd-463d-b5cf-4c2979e0dcac',
#       'name': 'violence-prevention',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'youth',
#       'id': 'd54cd1d0-b9fe-4ef0-922c-d49dcbba636c',
#       'name': 'youth',
#       'state': 'active',
#       'vocabulary_id': None}],
#     'title': 'Veto Violence - Violence Education Tools Online',
#     'tracking_summary': {'recent': 0, 'total': 0},
#     'type': 'dataset',
#     'url': None,
#     'version': None},
#    {'author': None,
#     'author_email': None,
#     'creator_user_id': '47303a9e-1187-4290-85a3-1fc02dc49e4a',
#     'extras': [{'key': 'publisher',
#       'value': 'Centers for Disease Control and Prevention'},
#      {'key': 'identifier', 'value': '68c80a71-e53c-46a9-af3a-f4a9e1ff57cd'},
#      {'key': 'harvest_source_id',
#       'value': '6ecff745-213b-4114-8230-3a6aed46a149'},
#      {'key': 'issued', 'value': '1999-01-01'},
#      {'key': 'resource-type', 'value': 'Dataset'},
#      {'key': 'modified', 'value': '1999-01-01'},
#      {'key': 'harvest_source_title', 'value': 'HHS CAS JSON'},
#      {'key': 'source_schema_version', 'value': '1.0'},
#      {'key': 'source_datajson_identifier', 'value': True},
#      {'key': 'dataQuality', 'value': True},
#      {'key': 'theme',
#       'value': ['Health Care Providers', 'Population Statistics', 'Safety']},
#      {'key': 'bureauCode', 'value': ['009:20']},
#      {'key': 'references',
#       'value': ['http://www.cdc.gov/violenceprevention/nvdrs/trainingtechnicalassist']},
#      {'key': 'spatial', 'value': '18 states'},
#      {'key': 'programCode', 'value': ['009:000']},
#      {'key': 'landingPage',
#       'value': 'http://www.cdc.gov/injury/wisqars/nvdrs'},
#      {'key': 'accessLevel', 'value': 'public'},
#      {'key': 'harvest_object_id',
#       'value': '19268c56-fb01-444d-9cad-08bea6d856ef'},
#      {'key': 'source_hash',
#       'value': 'd6a3ef8bffe7f07970aaebeb0dd917bf19dcc8b8'}],
#     'groups': [],
#     'id': '06e734bb-7942-4064-b99a-3b051e2cd99f',
#     'isopen': False,
#     'license_id': 'notspecified',
#     'license_title': 'License not specified',
#     'maintainer': 'nvrds@cdc.gov',
#     'maintainer_email': 'nvrds@cdc.gov',
#     'metadata_created': '2020-07-22T16:57:04.839089',
#     'metadata_modified': '2020-07-22T16:57:04.877851',
#     'name': 'national-violent-death-reporting-system-nvdrs-85604',
#     'notes': 'The National Violent Death Reporting System (NVDRS) provides states and communities with a clearer understanding of violent deaths to guide local decisions about efforts to prevent violence and helps them track progress over time. \r\n\r\nTo stop violent deaths, we must first understand all the facts. Created in 2002, the NVDRS is a surveillance system that pulls together data on violent deaths in 18 states (see map below), including information about homicides, such as homicides perpetrated by a intimate partner (e.g., boyfriend, girlfriend, wife, husband), child maltreatment (or child abuse) fatalities, suicides, deaths where individuals are killed by law enforcement in the line of duty, unintentional firearm injury deaths, and deaths of undetermined intent.\r\n\r\nThese data are supported by WISQARS, an interactive query system that provides data on injury deaths, violent deaths, and nonfatal injuries.',
#     'num_resources': 0,
#     'num_tags': 6,
#     'organization': {'approval_status': 'approved',
#      'created': '2013-08-26T15:35:30.958442',
#      'description': '',
#      'id': '3609164c-4c49-4a44-9179-23163027dc0a',
#      'image_url': 'https://www.hhs.gov/sites/default/files/web/images/seal_blue_gold_hi_res.jpg',
#      'is_organization': True,
#      'name': 'hhs-gov',
#      'revision_id': '30233016-f437-4829-9707-0116a827a3fe',
#      'state': 'active',
#      'title': 'U.S. Department of Health & Human Services',
#      'type': 'organization'},
#     'owner_org': '3609164c-4c49-4a44-9179-23163027dc0a',
#     'private': False,
#     'relationships_as_object': [],
#     'relationships_as_subject': [],
#     'resources': [],
#     'revision_id': 'af6b3a42-def9-4270-9970-72d98dd42acc',
#     'state': 'active',
#     'tags': [{'display_name': 'community-health',
#       'id': '0622d3d3-96ad-4ddc-91af-860a3c916a3a',
#       'name': 'community-health',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'injury-deaths',
#       'id': 'fce2a5d1-7cc1-48e4-a619-12db1732b44a',
#       'name': 'injury-deaths',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'nonfatal-injuries',
#       'id': '4179fb36-5b23-4c38-ae95-b9730c2310b4',
#       'name': 'nonfatal-injuries',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'sexual-assault',
#       'id': '9f97b647-bc00-4cbf-b430-ce2a707f33ca',
#       'name': 'sexual-assault',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'violent-deaths',
#       'id': 'b26999f2-1ad9-4fce-a226-3a5563e6661b',
#       'name': 'violent-deaths',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'ypll',
#       'id': 'eeeac8aa-df69-4e6e-8733-6fbfde7b2714',
#       'name': 'ypll',
#       'state': 'active',
#       'vocabulary_id': None}],
#     'title': 'National Violent Death Reporting System (NVDRS)',
#     'tracking_summary': {'recent': 0, 'total': 0},
#     'type': 'dataset',
#     'url': None,
#     'version': None},
#    {'author': None,
#     'author_email': None,
#     'creator_user_id': '47303a9e-1187-4290-85a3-1fc02dc49e4a',
#     'extras': [{'key': 'publisher',
#       'value': 'Substance Abuse & Mental Health Services Administration'},
#      {'key': 'identifier', 'value': '3ea82b25-e15d-452c-89a8-4fd9f32ec831'},
#      {'key': 'harvest_source_id',
#       'value': '6ecff745-213b-4114-8230-3a6aed46a149'},
#      {'key': 'issued', 'value': '2012-12-03'},
#      {'key': 'resource-type', 'value': 'Dataset'},
#      {'key': 'modified', 'value': '2012-12-03'},
#      {'key': 'harvest_source_title', 'value': 'HHS CAS JSON'},
#      {'key': 'source_schema_version', 'value': '1.0'},
#      {'key': 'source_datajson_identifier', 'value': True},
#      {'key': 'dataQuality', 'value': True},
#      {'key': 'theme',
#       'value': ['Health Care Providers', 'Safety', 'Treatments']},
#      {'key': 'bureauCode', 'value': ['009:30']},
#      {'key': 'spatial', 'value': 'Country'},
#      {'key': 'programCode', 'value': ['009:000']},
#      {'key': 'landingPage',
#       'value': 'http://findtreatment.samhsa.gov/MHTreatmentLocator/faces/about.jspx'},
#      {'key': 'accessLevel', 'value': 'public'},
#      {'key': 'harvest_object_id',
#       'value': '64492ef3-6a20-4f5f-9978-572844c81c31'},
#      {'key': 'source_hash',
#       'value': '6702de36775dff6ab7492e52271916612151a228'}],
#     'groups': [],
#     'id': '54440dd3-637a-49b0-8201-99667ee7763f',
#     'isopen': False,
#     'license_id': 'notspecified',
#     'license_title': 'License not specified',
#     'maintainer': 'Find Treatment',
#     'maintainer_email': 'findtreatment@samhsa.hhs.gov',
#     'metadata_created': '2020-07-22T16:57:17.832018',
#     'metadata_modified': '2020-07-22T16:57:17.860216',
#     'name': 'mental-health-treatement-facilities-locator-84840',
# ...
#     'version': None},
#    {'author': None,
#     'author_email': None,
#     'creator_user_id': '47303a9e-1187-4290-85a3-1fc02dc49e4a',
#     'extras': [{'key': 'publisher', 'value': 'opendata.maryland.gov'},
#      {'key': 'accessLevel', 'value': 'public'},
#      {'key': 'catalog_describedBy',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.json'},
#      {'key': 'harvest_source_id',
#       'value': 'c648abd8-55c8-48de-85db-cef6dad04adb'},
#      {'key': 'catalog_@context',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.jsonld'},
#      {'key': 'issued', 'value': '2019-04-23'},
#      {'key': 'resource-type', 'value': 'Dataset'},
#      {'key': 'modified', 'value': '2020-03-10'},
#      {'key': 'harvest_source_title', 'value': 'md json'},
#      {'key': 'source_schema_version', 'value': '1.1'},
#      {'key': 'source_datajson_identifier', 'value': True},
#      {'key': 'theme', 'value': ['Health and Human Services']},
#      {'key': 'catalog_@id',
#       'value': 'https://opendata.maryland.gov/data.json'},
#      {'key': 'catalog_conformsTo',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema'},
#      {'key': 'identifier',
#       'value': 'https://opendata.maryland.gov/api/views/neq8-2z7a'},
#      {'key': 'landingPage',
#       'value': 'https://opendata.maryland.gov/d/neq8-2z7a'},
#      {'key': 'harvest_object_id',
#       'value': 'd2f724e9-a806-41a7-bf14-bd017d7f489a'},
#      {'key': 'source_hash',
#       'value': '3197f935945cca888ce6eac913e2acadb53ff1a8'},
#      {'key': 'harvest_object_id',
#       'value': 'df767821-7732-43d8-a92f-c761b3db6311'},
#      {'key': 'harvest_source_id',
#       'value': 'c648abd8-55c8-48de-85db-cef6dad04adb'},
#      {'key': 'harvest_source_title', 'value': 'md json'}],
#     'groups': [{'description': 'Local Government Topic - for all datasets with state, local, county organizations',
#       'display_name': 'Local Government',
#       'id': 'ccc6c266-eee8-44bd-89aa-7cd8c4c6bf46',
#       'image_display_url': '',
#       'name': 'local',
#       'title': 'Local Government'}],
#     'id': 'd9483fee-b231-4dff-8a86-4cf5a3c146fa',
#     'isopen': False,
#     'license_id': 'notspecified',
#     'license_title': 'License not specified',
#     'maintainer': 'Tiffanie.Powell@maryland.gov',
#     'maintainer_email': 'no-reply@opendata.maryland.gov',
#     'metadata_created': '2019-03-18T17:38:21.511586',
#     'metadata_modified': '2020-09-20T18:11:26.996273',
#     'name': 'adolescents-who-received-a-wellness-checkup-in-the-last-year-2010-2016',
#     'notes': 'Adolescents Who Received A Wellness Checkup In The Last Year - This indicator reflects the percentage of adolescents (ages 13-20 years old) enrolled in Medicaid (320+ days) who received at least one well child visit during the past year. Adolescents are at heightened risk for a variety of poor health outcomes associated with: violence (homicide/suicide/intimate partner); injuries (motor vehicle/occupational/sports related); substance use and abuse; sexually transmitted infections, including HIV; unplanned pregnancies and homelessness. Well child visits provide the opportunity for health care providers to engage in primary, secondary, and tertiary prevention of poor health outcomes associated with these factors resulting in prevention, early detection, and treatment for issues that can otherwise have a life-long devastating impact on individuals.',
#     'num_resources': 4,
#     'num_tags': 6,
#     'organization': {'approval_status': 'approved',
#      'created': '2014-04-16T13:39:52.267852',
#      'description': '',
#      'id': 'ca91231f-8b5e-4368-87d9-b8baccae43b7',
#      'image_url': '',
#      'is_organization': True,
#      'name': 'state-of-maryland',
#      'revision_id': 'e1b8f622-9576-42ed-a198-fbb1888fe22d',
#      'state': 'active',
#      'title': 'State of Maryland',
#      'type': 'organization'},
#     'owner_org': 'ca91231f-8b5e-4368-87d9-b8baccae43b7',
#     'private': False,
#     'relationships_as_object': [],
#     'relationships_as_subject': [],
#     'resources': [{'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2019-03-18T17:38:21.552406',
#       'description': '',
#       'format': 'CSV',
#       'hash': '',
#       'id': '635390bc-c860-4ee7-8bbe-0bed3e8e454e',
#       'last_modified': None,
#       'mimetype': 'text/csv',
#       'mimetype_inner': None,
#       'name': 'Comma Separated Values File',
#       'no_real_name': 'True',
#       'package_id': 'd9483fee-b231-4dff-8a86-4cf5a3c146fa',
#       'position': 0,
#       'resource_type': None,
#       'revision_id': '8df96891-da05-4a85-87d0-f6db32e8987e',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 3, 'total': 6},
#       'url': 'https://opendata.maryland.gov/api/views/neq8-2z7a/rows.csv?accessType=DOWNLOAD',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None},
#      {'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2019-03-18T17:38:21.552432',
#       'describedBy': 'https://opendata.maryland.gov/api/views/neq8-2z7a/columns.rdf',
#       'describedByType': 'application/rdf+xml',
#       'description': '',
#       'format': 'RDF',
#       'hash': '',
#       'id': '739f77c7-fdca-4d2c-b7aa-45f200e2808b',
#       'last_modified': None,
#       'mimetype': 'application/rdf+xml',
#       'mimetype_inner': None,
#       'name': 'RDF File',
#       'no_real_name': 'True',
#       'package_id': 'd9483fee-b231-4dff-8a86-4cf5a3c146fa',
#       'position': 1,
#       'resource_type': None,
#       'revision_id': '1b72bf12-293b-4f4d-86c2-cd1d0b906f9e',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 1, 'total': 1},
#       'url': 'https://opendata.maryland.gov/api/views/neq8-2z7a/rows.rdf?accessType=DOWNLOAD',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None},
#      {'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2019-03-18T17:38:21.552442',
#       'describedBy': 'https://opendata.maryland.gov/api/views/neq8-2z7a/columns.json',
#       'describedByType': 'application/json',
#       'description': '',
#       'format': 'JSON',
#       'hash': '',
#       'id': 'f1d69db3-ba30-4bd8-819f-416c3c25801d',
#       'last_modified': None,
#       'mimetype': 'application/json',
#       'mimetype_inner': None,
#       'name': 'JSON File',
#       'no_real_name': 'True',
#       'package_id': 'd9483fee-b231-4dff-8a86-4cf5a3c146fa',
#       'position': 2,
#       'resource_type': None,
#       'revision_id': '1b72bf12-293b-4f4d-86c2-cd1d0b906f9e',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 0, 'total': 0},
#       'url': 'https://opendata.maryland.gov/api/views/neq8-2z7a/rows.json?accessType=DOWNLOAD',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None},
#      {'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2019-03-18T17:38:21.552452',
#       'describedBy': 'https://opendata.maryland.gov/api/views/neq8-2z7a/columns.svc',
#       'describedByType': 'application/xml',
#       'description': '',
#       'format': 'XML',
#       'hash': '',
#       'id': 'feea35a7-f214-4d2e-809a-e27120c8eb13',
#       'last_modified': None,
#       'mimetype': 'application/xml',
#       'mimetype_inner': None,
#       'name': 'XML File',
#       'no_real_name': 'True',
#       'package_id': 'd9483fee-b231-4dff-8a86-4cf5a3c146fa',
#       'position': 3,
#       'resource_type': None,
#       'revision_id': '1b72bf12-293b-4f4d-86c2-cd1d0b906f9e',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 1, 'total': 1},
#       'url': 'https://opendata.maryland.gov/api/views/neq8-2z7a/rows.xml?accessType=DOWNLOAD',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None}],
#     'revision_id': 'ad0c3da3-f8bf-49bc-98b2-7947a2a28347',
#     'state': 'active',
#     'tags': [{'display_name': 'child',
#       'id': 'b3b955d5-7a2e-452c-8d1d-b3f9a11ab96c',
#       'name': 'child',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'mdh',
#       'id': 'b3520790-dacb-429e-bd11-967bbe7136d3',
#       'name': 'mdh',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'medicaid',
#       'id': '6e127a56-4ac1-4d20-8282-8b5fe5ca201f',
#       'name': 'medicaid',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'ship',
#       'id': 'd1df245f-7be5-44e9-9354-acc6ad05457e',
#       'name': 'ship',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'state-health-improvement-process',
#       'id': '16bc7414-4df3-497d-af46-def25700fdba',
#       'name': 'state-health-improvement-process',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'wellness-check',
#       'id': 'e5d170b1-19ec-4712-a2f7-baefdce99ec9',
#       'name': 'wellness-check',
#       'state': 'active',
#       'vocabulary_id': None}],
#     'title': 'SHIP Adolescents Who Received A Wellness Checkup In The Last Year 2010-2017',
#     'tracking_summary': {'recent': 0, 'total': 20},
#     'type': 'dataset',
#     'url': None,
#     'version': None},
#    {'author': None,
#     'author_email': None,
#     'creator_user_id': '47303a9e-1187-4290-85a3-1fc02dc49e4a',
#     'extras': [{'key': 'publisher', 'value': 'data.mo.gov'},
#      {'key': 'accessLevel', 'value': 'public'},
#      {'key': 'catalog_describedBy',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.json'},
#      {'key': 'harvest_source_id',
#       'value': 'fb08af55-3229-4a6e-bd9b-4a362f9e2432'},
#      {'key': 'catalog_@context',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.jsonld'},
#      {'key': 'issued', 'value': '2013-05-06'},
#      {'key': 'resource-type', 'value': 'Dataset'},
#      {'key': 'modified', 'value': '2019-11-25'},
#      {'key': 'harvest_source_title', 'value': 'MO JSON'},
#      {'key': 'source_schema_version', 'value': '1.1'},
#      {'key': 'source_datajson_identifier', 'value': True},
#      {'key': 'theme', 'value': ['Health']},
#      {'key': 'catalog_@id', 'value': 'https://data.mo.gov/data.json'},
#      {'key': 'catalog_conformsTo',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema'},
#      {'key': 'identifier', 'value': 'https://data.mo.gov/api/views/kzf7-r4e9'},
#      {'key': 'landingPage', 'value': 'https://data.mo.gov/d/kzf7-r4e9'},
#      {'key': 'harvest_object_id',
#       'value': 'eda58197-e5dc-4ddb-82c4-84a706dde2b3'},
#      {'key': 'source_hash',
#       'value': '49bac67d8ed8df575f80d3e4d6a8bc4d1c4e700e'},
#      {'key': 'harvest_object_id',
#       'value': 'a33943ac-1ca8-4a78-b5db-c968c6bb0c00'},
#      {'key': 'harvest_source_id',
#       'value': 'fb08af55-3229-4a6e-bd9b-4a362f9e2432'},
#      {'key': 'harvest_source_title', 'value': 'MO JSON'}],
#     'groups': [{'description': 'Local Government Topic - for all datasets with state, local, county organizations',
#       'display_name': 'Local Government',
#       'id': 'ccc6c266-eee8-44bd-89aa-7cd8c4c6bf46',
#       'image_display_url': '',
#       'name': 'local',
#       'title': 'Local Government'}],
#     'id': '06ec840d-c220-48e6-8905-c95610fbaf0c',
#     'isopen': False,
#     'license_id': 'notspecified',
#     'license_title': 'License not specified',
#     'maintainer': 'Jon Sabala',
#     'maintainer_email': 'no-reply@data.mo.gov',
#     'metadata_created': '2015-09-03T04:44:39.373509',
#     'metadata_modified': '2020-09-20T18:12:42.568364',
#     'name': 'military-sexual-trauma-ed49a',
#     'notes': 'A collection of national resources on Military Sexual Trauma for service members, Veterans and their families.',
#     'num_resources': 1,
#     'num_tags': 10,
#     'organization': {'approval_status': 'approved',
#      'created': '2014-04-16T13:40:47.376105',
#      'description': '',
#      'id': '185a99df-1c20-42a2-a403-a978588f5cfe',
#      'image_url': '',
#      'is_organization': True,
#      'name': 'state-of-missouri',
#      'revision_id': '53281a94-8de8-4f2a-a4a3-d9ff67289f36',
#      'state': 'active',
#      'title': 'State of Missouri',
#      'type': 'organization'},
#     'owner_org': '185a99df-1c20-42a2-a403-a978588f5cfe',
#     'private': False,
#     'relationships_as_object': [],
#     'relationships_as_subject': [],
#     'resources': [{'archiver': '{\'is_broken_printable\': \'Not sure if broken\', \'updated\': \'2017-11-07T11:09:04.999359\', \'cache_filepath\': None, \'last_success\': None, \'size\': u\'0\', \'is_broken\': None, \'failure_count\': 1, \'etag\': None, \'status\': \'Download failure\', \'url_redirected_to\': None, \'hash\': None, \'status_id\': 22, \'reason\': u"\'SSLError\' object has no attribute \'reason\'", \'last_modified\': None, \'resource_timestamp\': \'2015-10-01T04:50:33.202581\', \'mimetype\': None, \'cache_url\': None, \'created\': \'2017-11-07T11:09:05.021001\', \'first_failure\': \'2017-11-07T11:09:04.999359\'}',
#       'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2015-09-03T00:44:39.795723',
#       'description': '',
#       'format': 'PDF',
#       'hash': '',
#       'id': 'e7513732-05c1-4515-8099-e740eccd3365',
#       'last_modified': None,
#       'mimetype': 'application/pdf',
#       'mimetype_inner': None,
#       'name': 'PDF File',
#       'no_real_name': 'True',
#       'package_id': '06ec840d-c220-48e6-8905-c95610fbaf0c',
#       'position': 0,
#       'qa': '{\'updated\': \'2017-11-08T21:27:52.591520\', \'openness_score\': 1, \'archival_timestamp\': \'2017-11-07T11:09:04.999359\', \'format\': u\'PDF\', \'created\': \'2017-11-08T21:27:52.598641\', \'resource_timestamp\': None, \'openness_score_reason\': u\'Could not determine a file extension in the URL. Format field "application/pdf" receives score: 1.\'}',
#       'resource_type': None,
#       'revision_id': '00fc3b9d-bcd5-45fa-ae1e-963fee3c148a',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 2, 'total': 44},
#       'url': 'https://data.mo.gov/download/kzf7-r4e9/application/pdf',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None}],
#     'revision_id': '6bb6eb8e-f31e-4f77-a3a2-a8371364084d',
#     'state': 'active',
#     'tags': [{'display_name': 'behavioral-health',
#       'id': 'ad766514-e155-4307-bbf2-8efba8cb5661',
#       'name': 'behavioral-health',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'family',
#       'id': '31916ac8-4ed1-4422-bddf-aa15bd5a0aac',
#       'name': 'family',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'mental-health',
#       'id': 'abc2b4a4-7230-42a6-9ad1-811cb34cc018',
#       'name': 'mental-health',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'mental-illness',
#       'id': '8bb032d4-1a45-472b-af16-20860fd702f9',
#       'name': 'mental-illness',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'military',
#       'id': '5a74f712-2921-45b2-b6ed-1a9282b9b77e',
#       'name': 'military',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'military-sexual-trauma',
#       'id': '516e282f-f636-42bd-9954-4aa6c005efa3',
#       'name': 'military-sexual-trauma',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'mst',
#       'id': '192e6c43-8673-4351-8e28-7c46a484198e',
#       'name': 'mst',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'service-member',
#       'id': '3d9febf7-a8ba-463e-a578-1052ceb83aca',
#       'name': 'service-member',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'suicide-prevention',
#       'id': 'fef70787-d881-4a82-9025-dac0c48d3c4b',
#       'name': 'suicide-prevention',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'veteran',
#       'id': '7561bea1-6f6c-4e42-96cc-7a5271ea4f8c',
#       'name': 'veteran',
#       'state': 'active',
#       'vocabulary_id': None}],
#     'title': 'Military Sexual Trauma',
#     'tracking_summary': {'recent': 0, 'total': 156},
#     'type': 'dataset',
#     'url': None,
#     'version': None}],
#   'search_facets': {},
#   'sort': 'views_recent desc'},
#  'success': True}

# %%
import json
import os.path

# !wget http://demo.ckan.org/api/3/action/package_search?q=spending

# Only queries the website once
# base_url = 'http://demo.ckan.org/api/3/action/'
base_url = 'http://catalog.data.gov/api/3/action/'
query = 'package_list'
if not os.path.exists(query):
  query_url = base_url + query
  # !wget {query_url}

with open (query, "r") as myfile:
  data = myfile.read()
  data = json.loads(data)
data
# Out:
# --2020-12-06 05:17:47--  http://catalog.data.gov/api/3/action/package_list
# Resolving catalog.data.gov (catalog.data.gov)... 13.32.240.94, 13.32.240.10, 13.32.240.71, ...
# Connecting to catalog.data.gov (catalog.data.gov)|13.32.240.94|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://catalog.data.gov/api/3/action/package_list [following]
# --2020-12-06 05:17:47--  https://catalog.data.gov/api/3/action/package_list
# Connecting to catalog.data.gov (catalog.data.gov)|13.32.240.94|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://catalog.data.gov/api/3/action/package_search [following]
# --2020-12-06 05:17:48--  https://catalog.data.gov/api/3/action/package_search
# Reusing existing connection to catalog.data.gov:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 98826 (97K) [application/json]
# Saving to: ‘package_list’
#
# package_list        100%[===================>]  96.51K   595KB/s    in 0.2s
#
# 2020-12-06 05:17:48 (595 KB/s) - ‘package_list’ saved [98826/98826]
# {'help': 'https://catalog.data.gov/api/3/action/help_show?name=package_search&host=&protocol=',
#  'result': {'count': 219382,
#   'facets': {},
#   'results': [{'author': None,
#     'author_email': None,
#     'creator_user_id': '47303a9e-1187-4290-85a3-1fc02dc49e4a',
#     'extras': [{'key': 'publisher',
#       'value': 'Allegheny County / City of Pittsburgh / Western PA Regional Data Center'},
#      {'key': 'identifier', 'value': '9e0ce87d-07b8-420c-a8aa-9de6104f61d6'},
#      {'key': 'license',
#       'value': 'http://www.opendefinition.org/licenses/cc-zero'},
#      {'key': 'harvest_source_id',
#       'value': '041cd86b-18ea-412b-8d67-2ed1d6124bbf'},
#      {'key': 'catalog_@context',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.jsonld'},
#      {'key': 'resource-type', 'value': 'Dataset'},
#      {'key': 'modified', 'value': '2018-05-02T05:57:21.847645'},
#      {'key': 'harvest_source_title', 'value': 'WPRDC data.json'},
#      {'key': 'source_schema_version', 'value': '1.1'},
#      {'key': 'source_datajson_identifier', 'value': True},
#      {'key': 'catalog_conformsTo',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema'},
#      {'key': 'accessLevel', 'value': 'public'},
#      {'key': 'harvest_object_id',
#       'value': 'ca2673a0-4f10-4bd4-a846-ca5ee162b745'},
#      {'key': 'source_hash',
#       'value': '774ebd0edf8fb8fa10e0d88ef25965fc79d93390'},
#      {'key': 'catalog_describedBy',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.json'},
#      {'key': 'harvest_object_id',
#       'value': 'ca2673a0-4f10-4bd4-a846-ca5ee162b745'},
#      {'key': 'harvest_source_id',
#       'value': '041cd86b-18ea-412b-8d67-2ed1d6124bbf'},
#      {'key': 'harvest_source_title', 'value': 'WPRDC data.json'}],
#     'groups': [{'description': 'Local Government Topic - for all datasets with state, local, county organizations',
#       'display_name': 'Local Government',
#       'id': 'ccc6c266-eee8-44bd-89aa-7cd8c4c6bf46',
#       'image_display_url': '',
#       'name': 'local',
#       'title': 'Local Government'}],
#     'id': '34f9f8aa-2fc8-4a37-9518-7286fa43cdb9',
#     'isopen': True,
#     'license_id': 'other-license-specified',
#     'license_title': 'Other License Specified',
#     'maintainer': 'Mary Beth Snyder',
#     'maintainer_email': 'LandHelp@AlleghenyCounty.us',
#     'metadata_created': '2016-06-21T03:44:12.260053',
#     'metadata_modified': '2018-08-03T19:59:52.995818',
#     'name': 'allegheny-county-property-sale-transactions',
#     'notes': 'This dataset contains data on all Real Property parcels that have sold since 2013 in Allegheny County, PA.\r\n\r\nBefore doing any market analysis on property sales, check the sales validation codes. Many property "sales" are not considered a valid representation of the true market value of the property. For example, when multiple lots are together on one deed with one price they are generally coded as invalid ("H") because the sale price for each parcel ID number indicates the total price paid for a group of parcels, not just for one parcel. See the Sales Validation Codes Dictionary for a complete explanation of valid and invalid sale codes.\r\n\r\nSales Transactions Disclaimer: Sales information is provided from the Allegheny County Department of Administrative Services, Real Estate Division. Content and validation codes are subject to change. Please review the Data Dictionary for details on included fields before each use. Property owners are not required by law to record a deed at the time of sale. Consequently the assessment system may not contain a complete sales history for every property and every sale. You may do a deed search at http://www.alleghenycounty.us/re/index.aspx directly for the most updated information.\r\nNote: Ordinance 3478-07 prohibits public access to search assessment records by owner name. It was signed by the Chief Executive in 2007.',
#     'num_resources': 7,
#     'num_tags': 8,
#     'organization': {'approval_status': 'approved',
#      'created': '2016-06-20T14:59:06.173417',
#      'description': 'Allegheny County (Pennsylvania) and the City of Pittsburgh both publish their data through the Western Pennsylvania Regional Data Center. The Western Pennsylvania Regional Data Center supports key community initiatives by making public information easier to find and use. The Data Center maintains Allegheny County and the City of Pittsburgh’s open data portal, and provides a number of services to data publishers and users. The Data Center also hosts datasets from these and other public sector agencies, academic institutions, and non-profit organizations. The Data Center is managed by the University of Pittsburgh’s Center for Social and Urban Research, and is a partnership of the University, Allegheny County and the City of Pittsburgh.',
#      'id': 'a7d30359-b403-426c-bc33-a1cf87d8e548',
#      'image_url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/7d/Seal_of_Pennsylvania.svg/1200px-Seal_of_Pennsylvania.svg.png',
#      'is_organization': True,
#      'name': 'allegheny-county-city-of-pittsburgh-western-pa-regional-data-center',
#      'revision_id': '782736ff-3fc3-45d1-b2e6-9a86069d3c13',
#      'state': 'active',
#      'title': 'Allegheny County / City of Pittsburgh / Western PA Regional Data Center',
#      'type': 'organization'},
#     'owner_org': 'a7d30359-b403-426c-bc33-a1cf87d8e548',
#     'private': False,
#     'relationships_as_object': [],
#     'relationships_as_subject': [],
#     'resources': [{'archiver': "{'is_broken_printable': 'Broken', 'updated': '2017-11-10T00:42:24.275716', 'cache_filepath': None, 'last_success': None, 'size': u'0', 'is_broken': True, 'failure_count': 1, 'etag': None, 'status': 'Download error', 'url_redirected_to': None, 'hash': None, 'status_id': 12, 'reason': u'Connection timed out after 20s', 'last_modified': None, 'resource_timestamp': '2017-05-12T07:02:01.536887', 'mimetype': None, 'cache_url': None, 'created': '2017-11-10T00:42:24.294485', 'first_failure': '2017-11-10T00:42:24.275716'}",
#       'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2017-05-12T07:02:01.712451',
#       'description': '',
#       'format': 'CSV',
#       'hash': '',
#       'id': '5a6688a2-d307-44a7-9bac-82af2f2b0509',
#       'last_modified': None,
#       'mimetype': 'text/csv',
#       'mimetype_inner': None,
#       'name': 'Property Sales Transactions',
#       'package_id': '34f9f8aa-2fc8-4a37-9518-7286fa43cdb9',
#       'position': 0,
#       'qa': "{'updated': '2017-11-15T22:42:21.442241', 'openness_score': 0, 'archival_timestamp': '2017-11-10T00:42:24.275716', 'format': None, 'created': '2017-11-15T22:42:21.445804', 'resource_timestamp': None, 'openness_score_reason': u'File could not be downloaded. Reason: Download error. Error details: Connection timed out after 20s. Attempted on 10/11/2017. This was the first attempt.'}",
#       'resource_type': None,
#       'revision_id': '238f6e4a-45cf-4e4d-8ae4-3ebdf1320b5a',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 16, 'total': 596},
#       'url': 'https://data.wprdc.org/datastore/dump/5bbe6c55-bce6-4edb-9d04-68edeb6bf7b1',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None},
#      {'archiver': '{\'is_broken_printable\': \'Downloaded OK\', \'updated\': \'2017-11-10T00:42:25.767842\', \'cache_filepath\': u\'None\', \'last_success\': \'2017-11-10T00:42:25.767842\', \'size\': u\'3\', \'is_broken\': False, \'failure_count\': 0, \'etag\': u\'"1457640252.57-299461"\', \'status\': \'Archived successfully\', \'url_redirected_to\': None, \'hash\': u\'None\', \'status_id\': 0, \'reason\': u\'\', \'last_modified\': u\'Thu, 10 Mar 2016 20:04:12 GMT\', \'resource_timestamp\': \'2017-01-05T14:03:50.532603\', \'mimetype\': u\'application/pdf\', \'cache_url\': u\'None\', \'created\': \'2017-11-10T00:42:25.780866\', \'first_failure\': None}',
#       'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2016-06-20T23:44:12.703623',
#       'description': 'property-sale-transactions-data-dictionaryrev.pdf',
#       'format': 'PDF',
#       'hash': '',
#       'id': '9279bc0d-6b08-44fc-9fa3-810563a4b2df',
#       'last_modified': None,
#       'mimetype': 'application/pdf',
#       'mimetype_inner': None,
#       'name': 'Property Sale Transactions Data Dictionary',
#       'package_id': '34f9f8aa-2fc8-4a37-9518-7286fa43cdb9',
#       'position': 1,
#       'qa': '{\'updated\': \'2017-11-15T22:42:21.454902\', \'openness_score\': 1, \'archival_timestamp\': \'2017-11-10T00:42:25.767842\', \'format\': u\'PDF\', \'created\': \'2017-11-15T22:42:21.460123\', \'resource_timestamp\': None, \'openness_score_reason\': u\'URL extension "pdf" relates to format "PDF" and receives score: 1.\'}',
#       'resource_type': None,
#       'revision_id': 'b5bb51b6-17bd-47e5-a9a7-95c3b79d6237',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 5, 'total': 114},
#       'url': 'https://data.wprdc.org/dataset/9e0ce87d-07b8-420c-a8aa-9de6104f61d6/resource/b5fdcafb-f037-4b4f-b86f-197687cf647f/download/property-sale-transactions-data-dictionaryrev.pdf',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None},
#      {'archiver': '{\'is_broken_printable\': \'Downloaded OK\', \'updated\': \'2017-11-10T00:42:26.273649\', \'cache_filepath\': u\'None\', \'last_success\': \'2017-11-10T00:42:26.273649\', \'size\': u\'3\', \'is_broken\': False, \'failure_count\': 0, \'etag\': u\'"1457638565.11-3547"\', \'status\': \'Archived successfully\', \'url_redirected_to\': None, \'hash\': u\'None\', \'status_id\': 0, \'reason\': u\'\', \'last_modified\': u\'Thu, 10 Mar 2016 19:36:05 GMT\', \'resource_timestamp\': \'2017-01-05T14:03:50.532603\', \'mimetype\': u\'text/csv\', \'cache_url\': u\'None\', \'created\': \'2017-11-10T00:42:26.286207\', \'first_failure\': None}',
#       'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2016-06-20T23:44:12.703632',
#       'description': 'property-sale-transaction-data-dictionary.csv',
#       'format': 'CSV',
#       'hash': '',
#       'id': '88846d71-f30f-4f6e-839b-c0d5f35c3935',
#       'last_modified': None,
#       'mimetype': 'text/csv',
#       'mimetype_inner': None,
#       'name': 'Property Sale Transactions Data Dictionary',
#       'package_id': '34f9f8aa-2fc8-4a37-9518-7286fa43cdb9',
#       'position': 2,
#       'qa': '{\'updated\': \'2017-11-15T22:42:21.468228\', \'openness_score\': 3, \'archival_timestamp\': \'2017-11-10T00:42:26.273649\', \'format\': u\'CSV\', \'created\': \'2017-11-15T22:42:21.472338\', \'resource_timestamp\': None, \'openness_score_reason\': u\'URL extension "csv" relates to format "CSV" and receives score: 3.\'}',
#       'resource_type': None,
#       'revision_id': 'b5bb51b6-17bd-47e5-a9a7-95c3b79d6237',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 5, 'total': 109},
#       'url': 'https://data.wprdc.org/dataset/9e0ce87d-07b8-420c-a8aa-9de6104f61d6/resource/72c092e5-b693-4bad-adff-2e6d0fda81b3/download/property-sale-transaction-data-dictionary.csv',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None},
#      {'archiver': '{\'is_broken_printable\': \'Downloaded OK\', \'updated\': \'2017-11-10T00:42:27.518397\', \'cache_filepath\': u\'None\', \'last_success\': \'2017-11-10T00:42:27.518397\', \'size\': u\'3\', \'is_broken\': False, \'failure_count\': 0, \'etag\': u\'"1444058749.55-447903"\', \'status\': \'Archived successfully\', \'url_redirected_to\': None, \'hash\': u\'None\', \'status_id\': 0, \'reason\': u\'\', \'last_modified\': u\'Mon, 05 Oct 2015 15:25:49 GMT\', \'resource_timestamp\': \'2017-01-05T14:03:50.532603\', \'mimetype\': u\'application/pdf\', \'cache_url\': u\'None\', \'created\': \'2017-11-10T00:42:27.528637\', \'first_failure\': None}',
#       'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2016-06-20T23:44:12.703640',
#       'description': 'sales-validation-codes-dictionary.pdf',
#       'format': 'PDF',
#       'hash': '',
#       'id': '161036fb-5644-4e06-9fae-e1835db0bf54',
#       'last_modified': None,
#       'mimetype': 'application/pdf',
#       'mimetype_inner': None,
#       'name': 'Sales Validation Codes Dictionary',
#       'package_id': '34f9f8aa-2fc8-4a37-9518-7286fa43cdb9',
#       'position': 3,
#       'qa': '{\'updated\': \'2017-11-15T22:42:21.484889\', \'openness_score\': 1, \'archival_timestamp\': \'2017-11-10T00:42:27.518397\', \'format\': u\'PDF\', \'created\': \'2017-11-15T22:42:21.490330\', \'resource_timestamp\': None, \'openness_score_reason\': u\'URL extension "pdf" relates to format "PDF" and receives score: 1.\'}',
#       'resource_type': None,
#       'revision_id': 'b5bb51b6-17bd-47e5-a9a7-95c3b79d6237',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 2, 'total': 15},
#       'url': 'https://data.wprdc.org/dataset/9e0ce87d-07b8-420c-a8aa-9de6104f61d6/resource/96474373-bcdb-42cf-af5d-3683e326e227/download/sales-validation-codes-dictionary.pdf',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None},
#      {'archiver': '{\'is_broken_printable\': \'Downloaded OK\', \'updated\': \'2017-11-10T00:42:28.188702\', \'cache_filepath\': u\'None\', \'last_success\': \'2017-11-10T00:42:28.188702\', \'size\': u\'3\', \'is_broken\': False, \'failure_count\': 0, \'etag\': u\'"1444058876.54-9432"\', \'status\': \'Archived successfully\', \'url_redirected_to\': None, \'hash\': u\'None\', \'status_id\': 0, \'reason\': u\'\', \'last_modified\': u\'Mon, 05 Oct 2015 15:27:56 GMT\', \'resource_timestamp\': \'2017-01-05T14:03:50.532603\', \'mimetype\': u\'text/csv\', \'cache_url\': u\'None\', \'created\': \'2017-11-10T00:42:28.199162\', \'first_failure\': None}',
#       'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2016-06-20T23:44:12.703648',
#       'description': 'sales-validation-codes-dictionary.csv',
#       'format': 'CSV',
#       'hash': '',
#       'id': '3cb0f626-b4b8-43a7-bfac-a972844faf77',
#       'last_modified': None,
#       'mimetype': 'text/csv',
#       'mimetype_inner': None,
#       'name': 'Sales Validation Codes Dictionary',
#       'package_id': '34f9f8aa-2fc8-4a37-9518-7286fa43cdb9',
#       'position': 4,
#       'qa': '{\'updated\': \'2017-11-15T22:42:21.499055\', \'openness_score\': 3, \'archival_timestamp\': \'2017-11-10T00:42:28.188702\', \'format\': u\'CSV\', \'created\': \'2017-11-15T22:42:21.503927\', \'resource_timestamp\': None, \'openness_score_reason\': u\'URL extension "csv" relates to format "CSV" and receives score: 3.\'}',
#       'resource_type': None,
#       'revision_id': 'b5bb51b6-17bd-47e5-a9a7-95c3b79d6237',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 2, 'total': 24},
#       'url': 'https://data.wprdc.org/dataset/9e0ce87d-07b8-420c-a8aa-9de6104f61d6/resource/5144e253-2613-46eb-9379-3f6a65a360bc/download/sales-validation-codes-dictionary.csv',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None},
#      {'archiver': "{'is_broken_printable': 'Downloaded OK', 'updated': '2017-11-10T00:42:29.385263', 'cache_filepath': u'None', 'last_success': '2017-11-10T00:42:29.385263', 'size': u'3', 'is_broken': False, 'failure_count': 0, 'etag': None, 'status': 'Archived successfully', 'url_redirected_to': None, 'hash': u'None', 'status_id': 0, 'reason': u'', 'last_modified': None, 'resource_timestamp': '2017-01-05T14:03:50.532603', 'mimetype': u'text/html', 'cache_url': u'None', 'created': '2017-11-10T00:42:29.396046', 'first_failure': None}",
#       'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2016-06-20T23:44:12.703655',
#       'description': 'home.aspx',
#       'format': 'HTML',
#       'hash': '',
#       'id': '96e9b441-d769-4a91-8619-05ac91b3b517',
#       'last_modified': None,
#       'mimetype': 'text/html',
#       'mimetype_inner': None,
#       'name': 'Allegheny County Information Portal Real Estate Sales',
#       'package_id': '34f9f8aa-2fc8-4a37-9518-7286fa43cdb9',
#       'position': 5,
#       'qa': '{\'updated\': \'2017-11-15T22:42:21.516552\', \'openness_score\': 0, \'archival_timestamp\': \'2017-11-10T00:42:29.385263\', \'format\': u\'HTML\', \'created\': \'2017-11-15T22:42:21.521977\', \'resource_timestamp\': None, \'openness_score_reason\': u\'URL extension "aspx" is an unknown format. Format field "HTML" receives score: 0.\'}',
#       'resource_type': None,
#       'revision_id': 'b5bb51b6-17bd-47e5-a9a7-95c3b79d6237',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 6, 'total': 114},
#       'url': 'http://infoportal.alleghenycounty.us/resalesdata/home.aspx',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None},
#      {'archiver': '{\'is_broken_printable\': \'Downloaded OK\', \'updated\': \'2017-11-10T00:42:29.632986\', \'cache_filepath\': u\'None\', \'last_success\': \'2017-11-10T00:42:29.632986\', \'size\': u\'3\', \'is_broken\': False, \'failure_count\': 0, \'etag\': u\'W/"59e9196f-3ae"\', \'status\': \'Archived successfully\', \'url_redirected_to\': None, \'hash\': u\'None\', \'status_id\': 0, \'reason\': u\'\', \'last_modified\': u\'Thu, 19 Oct 2017 21:30:23 GMT\', \'resource_timestamp\': \'2017-03-30T11:58:01.302473\', \'mimetype\': u\'text/html\', \'cache_url\': u\'None\', \'created\': \'2017-11-10T00:42:29.650706\', \'first_failure\': None}',
#       'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2017-03-30T11:58:01.461331',
#       'description': '',
#       'format': 'HTML',
#       'hash': '',
#       'id': '02d7b4af-0ada-4122-94e5-03c02e71f0dd',
#       'last_modified': None,
#       'mimetype': 'text/html',
#       'mimetype_inner': None,
#       'name': 'Property Dashboard',
#       'package_id': '34f9f8aa-2fc8-4a37-9518-7286fa43cdb9',
#       'position': 6,
#       'qa': '{\'updated\': \'2017-11-15T22:42:21.532604\', \'openness_score\': 0, \'archival_timestamp\': \'2017-11-10T00:42:29.632986\', \'format\': u\'HTML\', \'created\': \'2017-11-15T22:42:21.538059\', \'resource_timestamp\': None, \'openness_score_reason\': u\'Could not determine a file extension in the URL. Format field "HTML" receives score: 0.\'}',
#       'resource_type': None,
#       'revision_id': 'ab2d58b5-269e-48ec-8bb9-9967b2ac2b28',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 4, 'total': 90},
#       'url': 'http://tools.wprdc.org/property-dashboard/',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None}],
#     'revision_id': 'f223acaf-a616-4bce-8957-41a68bc5004d',
#     'state': 'active',
#     'tags': [{'display_name': '_etl',
#       'id': 'f8274170-aa7d-421d-881a-a75e0278a880',
#       'name': '_etl',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'etl',
#       'id': '361eefee-5474-48ef-ac59-d5508d47f9a1',
#       'name': 'etl',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'housing',
#       'id': 'cc2a8aab-2dfe-453c-927b-2c7669dad222',
#       'name': 'housing',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'parcel',
#       'id': '01166bf1-a271-40b3-9def-6122c7820467',
#       'name': 'parcel',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'property',
#       'id': '9c6026e6-9700-431f-812d-cf9fb4d21f30',
#       'name': 'property',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'real-estate',
#       'id': '644c8b8c-1717-402d-978d-a20b24c89832',
#       'name': 'real-estate',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'real-property',
#       'id': 'f95ca7ac-23f2-4898-bf9d-940e5a652e81',
#       'name': 'real-property',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'sales',
#       'id': '8cad3f01-0f4c-42e8-9048-8adfaffd8c9f',
#       'name': 'sales',
#       'state': 'active',
#       'vocabulary_id': None}],
#     'title': 'Allegheny County Property Sale Transactions',
#     'tracking_summary': {'recent': 118, 'total': 4575},
#     'type': 'dataset',
#     'url': None,
#     'version': None},
#    {'author': None,
#     'author_email': None,
#     'creator_user_id': '47303a9e-1187-4290-85a3-1fc02dc49e4a',
#     'extras': [{'key': 'bbox-east-long', 'value': '-63.669317'},
#      {'key': 'harvest_source_id',
#       'value': 'd2b8ee7a-2d57-4490-83dd-7875815fb0d8'},
#      {'key': 'resource-type', 'value': 'dataset'},
#      {'key': 'bbox-north-lat', 'value': '64.802932'},
#      {'key': 'coupled-resource', 'value': '[]'},
#      {'key': 'guid', 'value': ''},
#      {'key': 'spatial_harvester', 'value': True},
#      {'key': 'bbox-south-lat', 'value': '13.397614'},
#      {'key': '__category_tag_78473e2f-b6ba-4e28-b0c1-d53c35a7e010',
#       'value': '["Infrastructure","Geospatial"]'},
#      {'key': 'spatial-reference-system', 'value': ''},
#      {'key': 'spatial',
#       'value': '{"type": "Polygon", "coordinates": [[[-159.666594, 13.397614], [-63.669317, 13.397614], [-63.669317, 64.802932], [-159.666594, 64.802932], [-159.666594, 13.397614]]]}'},
#      {'key': 'progress', 'value': ''},
#      {'key': 'access_constraints',
#       'value': '["Use Constraints: For Official Use Only (FOUO); no other use constraints.", "Access Constraints: None"]'},
#      {'key': 'contact-email', 'value': 'nid@usace.army.mil'},
#      {'key': 'bbox-west-long', 'value': '-159.666594'},
#      {'key': 'metadata-date', 'value': '2015-04-15'},
#      {'key': 'dataset-reference-date',
#       'value': '[{"type": "publication", "value": "2013-05-01"}]'},
#      {'key': 'harvest_source_title',
#       'value': 'FGDC WAF (Hosted by DOI for Geoplatform.gov)'},
#      {'key': 'frequency-of-update', 'value': ''},
#      {'key': 'licence', 'value': '[" "]'},
#      {'key': 'metadata_type', 'value': 'geospatial'},
#      {'key': 'harvest_object_id',
#       'value': '1cfbbef1-d793-49c8-81da-3ed224a82825'},
#      {'key': 'responsible-party',
#       'value': '[{"name": "U.S. Army Corps of Engineers", "roles": ["pointOfContact"]}]'},
#      {'key': 'spatial-data-service-type', 'value': ''},
#      {'key': 'metadata-language', 'value': ''},
#      {'key': 'tags',
#       'value': 'ngda, dams, national geospatial data asset, national inventory of dams, water inland theme'},
#      {'key': 'harvest_object_id',
#       'value': '1cfbbef1-d793-49c8-81da-3ed224a82825'},
#      {'key': 'harvest_source_id',
#       'value': 'd2b8ee7a-2d57-4490-83dd-7875815fb0d8'},
#      {'key': 'harvest_source_title',
#       'value': 'FGDC WAF (Hosted by DOI for Geoplatform.gov)'}],
#     'groups': [{'description': 'Maritime Topic',
#       'display_name': 'Maritime',
#       'id': '78473e2f-b6ba-4e28-b0c1-d53c35a7e010',
#       'image_display_url': '',
#       'name': 'maritime',
#       'title': 'Maritime'}],
#     'id': '871c3756-0dfd-4f0e-9de4-47692a66d7ef',
#     'isopen': True,
#     'license_id': 'us-pd',
#     'license_title': 'U.S. Government Work',
#     'license_url': 'http://www.usa.gov/publicdomain/label/1.0/',
#     'maintainer': None,
#     'maintainer_email': None,
#     'metadata_created': '2015-04-20T21:06:46.552327',
#     'metadata_modified': '2017-12-06T15:57:17.690257',
#     'name': 'national-inventory-of-dams',
#     'notes': "The National Inventory of Dams (NID) is a congressionally authorized database documenting dams in the United Staets and its territories. It is maintained and published by the US Army Corps of Engineers. It contains information about a dam's location, size, purpose, type, last inspection and regulatory facts. More information can be found at http://nid.usace.army.mil/.",
#     'num_resources': 1,
#     'num_tags': 0,
#     'organization': {'approval_status': 'approved',
#      'created': '2013-03-21T19:39:06.358236',
#      'description': '',
#      'id': 'ace19361-84f5-4b61-aaa0-fdd668f31f18',
#      'image_url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/ab/US-FederalGeographicDataCommittee-Logo.svg/220px-US-FederalGeographicDataCommittee-Logo.svg.png',
#      'is_organization': True,
#      'name': 'fgdc-gov',
#      'revision_id': '3967ecc9-3aa7-4122-8469-5cba3ed12a38',
#      'state': 'active',
#      'title': 'Federal Geographic Data Committee',
#      'type': 'organization'},
#     'owner_org': 'ace19361-84f5-4b61-aaa0-fdd668f31f18',
#     'private': False,
#     'relationships_as_object': [],
#     'relationships_as_subject': [],
#     'resources': [{'archiver': '{\'is_broken_printable\': \'Downloaded OK\', \'updated\': \'2017-11-17T23:02:58.922516\', \'cache_filepath\': u\'None\', \'last_success\': \'2017-11-17T23:02:58.922516\', \'size\': u\'3\', \'is_broken\': False, \'failure_count\': 0, \'etag\': u\'W/"11292-1426098428265"\', \'status\': \'Archived successfully\', \'url_redirected_to\': None, \'hash\': u\'None\', \'status_id\': 0, \'reason\': u\'\', \'last_modified\': u\'Wed, 11 Mar 2015 18:27:08 GMT\', \'resource_timestamp\': \'2016-08-02T23:09:37.413319\', \'mimetype\': u\'text/html\', \'cache_url\': u\'None\', \'created\': \'2017-11-17T23:02:58.938206\', \'first_failure\': None}',
#       'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2015-04-20T17:06:47.246319',
#       'description': '',
#       'format': '',
#       'hash': '',
#       'id': '5243a0d2-2a97-4678-bbfd-f85a81d7a134',
#       'last_modified': None,
#       'mimetype': None,
#       'mimetype_inner': None,
#       'name': 'Web Page',
#       'no_real_name': 'True',
#       'package_id': '871c3756-0dfd-4f0e-9de4-47692a66d7ef',
#       'position': 0,
#       'qa': "{'updated': '2017-11-21T12:17:15.479200', 'openness_score': 1, 'archival_timestamp': '2017-11-17T23:02:58.922516', 'format': None, 'created': '2017-11-21T12:17:15.488091', 'resource_timestamp': None, 'openness_score_reason': u'Could not determine a file extension in the URL. Format field is blank. Could not understand the file format, therefore score is 1.'}",
#       'resource_locator_function': '',
#       'resource_locator_protocol': '',
#       'resource_type': None,
#       'revision_id': 'ad2aa676-5b13-47e2-94ba-28cb06f05da0',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 45, 'total': 2393},
#       'url': 'http://geoplatform.usace.army.mil/home/',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None}],
#     'revision_id': '478c304c-460a-4abd-928b-16f0003e4a6d',
#     'state': 'active',
#     'tags': [],
#     'title': 'National Inventory of Dams',
#     'tracking_summary': {'recent': 104, 'total': 7802},
#     'type': 'dataset',
#     'url': None,
#     'version': None},
#    {'author': None,
#     'author_email': None,
#     'creator_user_id': '47303a9e-1187-4290-85a3-1fc02dc49e4a',
#     'extras': [{'key': 'publisher',
#       'value': 'Allegheny County / City of Pittsburgh / Western PA Regional Data Center'},
#      {'key': 'identifier', 'value': '1e310bc4-87f5-4e56-b04c-38bd8c9ed954'},
#      {'key': 'license',
#       'value': 'http://www.opendefinition.org/licenses/cc-zero'},
#      {'key': 'harvest_source_id',
#       'value': '041cd86b-18ea-412b-8d67-2ed1d6124bbf'},
#      {'key': 'catalog_@context',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.jsonld'},
#      {'key': 'resource-type', 'value': 'Dataset'},
#      {'key': 'modified', 'value': '2017-02-27T19:20:49.562488'},
#      {'key': 'harvest_source_title', 'value': 'WPRDC data.json'},
#      {'key': 'source_schema_version', 'value': '1.1'},
#      {'key': 'source_datajson_identifier', 'value': True},
#      {'key': 'theme', 'value': ['geospatial']},
#      {'key': 'metadata_type', 'value': 'geospatial'},
#      {'key': 'catalog_conformsTo',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema'},
#      {'key': 'accessLevel', 'value': 'public'},
#      {'key': 'harvest_object_id',
#       'value': '7f671130-68bb-4c53-8cb5-12a9f39a563c'},
#      {'key': 'source_hash',
#       'value': '6a54bb195a88eb247994a0668c297983425f0517'},
#      {'key': 'catalog_describedBy',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.json'},
#      {'key': 'harvest_object_id',
#       'value': '7f671130-68bb-4c53-8cb5-12a9f39a563c'},
#      {'key': 'harvest_source_id',
#       'value': '041cd86b-18ea-412b-8d67-2ed1d6124bbf'},
#      {'key': 'harvest_source_title', 'value': 'WPRDC data.json'}],
#     'groups': [{'description': 'Local Government Topic - for all datasets with state, local, county organizations',
#       'display_name': 'Local Government',
#       'id': 'ccc6c266-eee8-44bd-89aa-7cd8c4c6bf46',
#       'image_display_url': '',
#       'name': 'local',
#       'title': 'Local Government'}],
#     'id': 'd61d2de0-1913-432d-9370-b18f0fca5a4e',
#     'isopen': True,
#     'license_id': 'other-license-specified',
#     'license_title': 'Other License Specified',
#     'maintainer': 'Western Pennsylvania Regional Data Center',
#     'maintainer_email': 'wprdc@pitt.edu',
#     'metadata_created': '2016-06-21T03:44:36.304475',
#     'metadata_modified': '2017-03-02T20:44:42.575560',
#     'name': 'pittsburgh-neighborhoods-map',
#     'notes': 'Allows users to look up City of Pittsburgh Neighborhoods',
#     'num_resources': 1,
#     'num_tags': 3,
#     'organization': {'approval_status': 'approved',
#      'created': '2016-06-20T14:59:06.173417',
#      'description': 'Allegheny County (Pennsylvania) and the City of Pittsburgh both publish their data through the Western Pennsylvania Regional Data Center. The Western Pennsylvania Regional Data Center supports key community initiatives by making public information easier to find and use. The Data Center maintains Allegheny County and the City of Pittsburgh’s open data portal, and provides a number of services to data publishers and users. The Data Center also hosts datasets from these and other public sector agencies, academic institutions, and non-profit organizations. The Data Center is managed by the University of Pittsburgh’s Center for Social and Urban Research, and is a partnership of the University, Allegheny County and the City of Pittsburgh.',
#      'id': 'a7d30359-b403-426c-bc33-a1cf87d8e548',
#      'image_url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/7d/Seal_of_Pennsylvania.svg/1200px-Seal_of_Pennsylvania.svg.png',
#      'is_organization': True,
#      'name': 'allegheny-county-city-of-pittsburgh-western-pa-regional-data-center',
#      'revision_id': '782736ff-3fc3-45d1-b2e6-9a86069d3c13',
#      'state': 'active',
#      'title': 'Allegheny County / City of Pittsburgh / Western PA Regional Data Center',
#      'type': 'organization'},
#     'owner_org': 'a7d30359-b403-426c-bc33-a1cf87d8e548',
#     'private': False,
#     'relationships_as_object': [],
#     'relationships_as_subject': [],
#     'resources': [{'archiver': '{\'is_broken_printable\': \'Downloaded OK\', \'updated\': \'2017-12-09T05:04:24.645502\', \'cache_filepath\': u\'None\', \'last_success\': \'2017-12-09T05:04:24.645502\', \'size\': u\'3\', \'is_broken\': False, \'failure_count\': 0, \'etag\': u\'W/"fe7060b2a3354fa815088461d35be3d4"\', \'status\': \'Archived successfully\', \'url_redirected_to\': None, \'hash\': u\'None\', \'status_id\': 0, \'reason\': u\'\', \'last_modified\': u\'Thu, 07 Dec 2017 04:32:15 GMT\', \'resource_timestamp\': \'2017-01-05T14:03:19.570497\', \'mimetype\': u\'text/html\', \'cache_url\': u\'None\', \'created\': \'2017-12-09T05:04:24.655802\', \'first_failure\': None}',
#       'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2016-06-20T23:44:36.521928',
#       'description': '',
#       'format': 'HTML',
#       'hash': '',
#       'id': '239eea00-9fe1-4d08-918f-f641a376ce3a',
#       'last_modified': None,
#       'mimetype': 'text/html',
#       'mimetype_inner': None,
#       'name': 'Pittsburgh Neighborhoods',
#       'package_id': 'd61d2de0-1913-432d-9370-b18f0fca5a4e',
#       'position': 0,
#       'qa': '{\'updated\': \'2017-12-09T10:23:07.999646\', \'openness_score\': 1, \'archival_timestamp\': \'2017-12-09T05:04:24.645502\', \'format\': u\'HTML\', \'created\': \'2017-12-09T10:09:19.854393\', \'resource_timestamp\': None, \'openness_score_reason\': u\'URL extension "html" relates to format "HTML" but a score for that format is not configured, so giving it default score 1.\'}',
#       'resource_type': None,
#       'revision_id': 'd5eab28b-db25-498c-b968-1f72d29f7bb0',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 30, 'total': 903},
#       'url': 'https://pittsburghpa.maps.arcgis.com/apps/OnePane/basicviewer/index.html?appid=7b284a2998454505a6f000d24ee1ded5',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None}],
#     'revision_id': 'c004defd-9795-444d-a5d1-00aca4178aa7',
#     'state': 'active',
#     'tags': [{'display_name': 'map',
#       'id': '4b25baf2-c254-4949-8996-e9c3895fa2b6',
#       'name': 'map',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'neighborhoods',
#       'id': '0bf7396f-6631-4fb2-b887-9c7b189a35a8',
#       'name': 'neighborhoods',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'pittsburgh',
#       'id': '81e11e16-0ac5-4167-aa18-13abd2d5f5d9',
#       'name': 'pittsburgh',
#       'state': 'active',
#       'vocabulary_id': None}],
#     'title': 'Pittsburgh Neighborhoods Map',
#     'tracking_summary': {'recent': 101, 'total': 2990},
#     'type': 'dataset',
#     'url': None,
#     'version': None},
#    {'author': None,
#     'author_email': None,
#     'creator_user_id': '47303a9e-1187-4290-85a3-1fc02dc49e4a',
#     'extras': [{'key': 'publisher',
#       'value': 'National Oceanic and Atmospheric Administration - National Centers for Environmental Information'},
#      {'key': 'catalog_@context',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.jsonld'},
#      {'key': 'accessLevel', 'value': 'public'},
#      {'key': 'language', 'value': ['en']},
#      {'key': 'harvest_source_id',
#       'value': 'a8cb32c0-8890-4b57-a365-d5d84daefe01'},
#      {'key': 'rights', 'value': 'Open Database License (ODbL)'},
#      {'key': 'resource-type', 'value': 'Dataset'},
#      {'key': 'modified', 'value': '2016-02-14T02:54:45+00:00'},
#      {'key': 'harvest_source_title',
#       'value': 'Town of Cary, NC Data.json Harvest Source'},
#      {'key': 'source_schema_version', 'value': '1.1'},
#      {'key': 'source_datajson_identifier', 'value': True},
#      {'key': 'theme', 'value': ['Environment']},
#      {'key': 'catalog_@id', 'value': 'https://data.townofcary.org/data.json'},
#      {'key': 'catalog_conformsTo',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema'},
#      {'key': 'identifier', 'value': 'rdu-weather-history'},
#      {'key': 'landingPage',
#       'value': 'https://data.townofcary.org/explore/dataset/rdu-weather-history/'},
#      {'key': 'harvest_object_id',
#       'value': '5adef431-c070-4e69-868c-5082d9b0a772'},
#      {'key': 'source_hash',
#       'value': 'fefeccbdefbdcd4ef46e0cd8048489ed5bff5eb5'},
#      {'key': 'catalog_describedBy',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.json'},
#      {'key': 'harvest_object_id',
#       'value': '5adef431-c070-4e69-868c-5082d9b0a772'},
#      {'key': 'harvest_source_id',
#       'value': 'a8cb32c0-8890-4b57-a365-d5d84daefe01'},
#      {'key': 'harvest_source_title',
#       'value': 'Town of Cary, NC Data.json Harvest Source'}],
#     'groups': [{'description': 'Local Government Topic - for all datasets with state, local, county organizations',
#       'display_name': 'Local Government',
#       'id': 'ccc6c266-eee8-44bd-89aa-7cd8c4c6bf46',
#       'image_display_url': '',
#       'name': 'local',
#       'title': 'Local Government'}],
#     'id': '436a875e-9440-4c6f-8b13-c8deb71466d6',
#     'isopen': False,
#     'license_id': 'notspecified',
#     'license_title': 'License not specified',
#     'maintainer': '<Nobody>',
#     'maintainer_email': None,
#     'metadata_created': '2017-02-10T23:45:12.338638',
#     'metadata_modified': '2017-07-22T21:50:51.971207',
#     'name': 'local-weather-archive',
#     'notes': '<p>Pull weather data as collected at Raleigh-Durham International Airport by NOAA.</p><p>This dataset contains Raleigh Durham International Airport\xa0weather data pulled from the NOAA\xa0web service described at:</p><p><a href="http://www.ncdc.noaa.gov/cdo-web/webservices/v2">http://www.ncdc.noaa.gov/cdo-web/webservices/v2</a></p><p>We have pulled this data and converted the data to commonly used units.\xa0</p>',
#     'num_resources': 3,
#     'num_tags': 3,
#     'organization': {'approval_status': 'approved',
#      'created': '2017-02-10T21:16:57.646643',
#      'description': '',
#      'id': '4f1f9ab0-52e4-43f1-b683-1f94e6f7ea91',
#      'image_url': 'https://data.townofcary.org/assets/theme_image/townofcarybanner.png',
#      'is_organization': True,
#      'name': 'town-of-cary-north-carolina',
#      'revision_id': '41ef9198-31c3-4041-88dc-8c2201018abd',
#      'state': 'active',
#      'title': 'Town of Cary, North Carolina',
#      'type': 'organization'},
#     'owner_org': '4f1f9ab0-52e4-43f1-b683-1f94e6f7ea91',
#     'private': False,
#     'relationships_as_object': [],
#     'relationships_as_subject': [],
#     'resources': [{'archiver': "{'is_broken_printable': 'Downloaded OK', 'updated': '2017-11-15T03:50:49.020632', 'cache_filepath': u'None', 'last_success': '2017-11-15T03:50:49.020632', 'size': u'3', 'is_broken': False, 'failure_count': 0, 'etag': None, 'status': 'Archived successfully', 'url_redirected_to': None, 'hash': u'None', 'status_id': 0, 'reason': u'', 'last_modified': None, 'resource_timestamp': '2017-07-22T21:50:51.952631', 'mimetype': u'application/json', 'cache_url': u'None', 'created': '2017-11-15T03:50:49.035020', 'first_failure': None}",
#       'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2017-07-22T21:50:52.061244',
#       'description': '',
#       'format': 'JSON',
#       'hash': '',
#       'id': 'c28974a2-fc83-4722-8977-9a701323f729',
#       'last_modified': None,
#       'mimetype': '',
#       'mimetype_inner': None,
#       'name': 'JSON File',
#       'no_real_name': 'True',
#       'package_id': '436a875e-9440-4c6f-8b13-c8deb71466d6',
#       'position': 0,
#       'qa': '{\'updated\': \'2017-11-19T12:04:47.475435\', \'openness_score\': 3, \'archival_timestamp\': \'2017-11-15T03:50:49.020632\', \'format\': u\'JSON\', \'created\': \'2017-11-19T12:04:47.498591\', \'resource_timestamp\': None, \'openness_score_reason\': u\'Could not determine a file extension in the URL. Format field "JSON" receives score: 3.\'}',
#       'resource_type': None,
#       'revision_id': '9fca47f5-12ee-42a0-9761-0903adfe14af',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 11, 'total': 239},
#       'url': 'https://data.townofcary.org/api/v2/catalog/datasets/rdu-weather-history',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None},
#      {'archiver': "{'is_broken_printable': 'Downloaded OK', 'updated': '2017-11-15T03:50:49.420429', 'cache_filepath': u'None', 'last_success': '2017-11-15T03:50:49.420429', 'size': u'3', 'is_broken': False, 'failure_count': 0, 'etag': None, 'status': 'Archived successfully', 'url_redirected_to': None, 'hash': u'None', 'status_id': 0, 'reason': u'', 'last_modified': None, 'resource_timestamp': '2017-07-22T21:50:51.952631', 'mimetype': u'application/json', 'cache_url': u'None', 'created': '2017-11-15T03:50:49.436478', 'first_failure': None}",
#       'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2017-07-22T21:50:52.061260',
#       'description': '',
#       'format': 'JSON',
#       'hash': '',
#       'id': '8804379b-de9c-4229-9e74-f10c5d9fba10',
#       'last_modified': None,
#       'mimetype': 'application/json',
#       'mimetype_inner': None,
#       'name': 'JSON File',
#       'no_real_name': 'True',
#       'package_id': '436a875e-9440-4c6f-8b13-c8deb71466d6',
#       'position': 1,
#       'qa': '{\'updated\': \'2017-11-19T12:04:47.611572\', \'openness_score\': 3, \'archival_timestamp\': \'2017-11-15T03:50:49.420429\', \'format\': u\'JSON\', \'created\': \'2017-11-19T12:04:47.620526\', \'resource_timestamp\': None, \'openness_score_reason\': u\'Could not determine a file extension in the URL. Format field "JSON" receives score: 3.\'}',
#       'resource_type': None,
#       'revision_id': '9fca47f5-12ee-42a0-9761-0903adfe14af',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 11, 'total': 135},
#       'url': 'https://data.townofcary.org/api/v2/catalog/datasets/rdu-weather-history/exports/json',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None},
#      {'archiver': '{\'is_broken_printable\': \'Broken\', \'updated\': \'2017-11-15T03:50:50.027815\', \'cache_filepath\': None, \'last_success\': None, \'size\': u\'0\', \'is_broken\': True, \'failure_count\': 1, \'etag\': None, \'status\': \'Download error\', \'url_redirected_to\': None, \'hash\': None, \'status_id\': 12, \'reason\': u"Error with the download: local variable \'saved_chunk\' referenced before assignment", \'last_modified\': None, \'resource_timestamp\': \'2017-07-22T21:50:51.952631\', \'mimetype\': None, \'cache_url\': None, \'created\': \'2017-11-15T03:50:50.037384\', \'first_failure\': \'2017-11-15T03:50:50.027815\'}',
#       'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2017-07-22T21:50:52.061264',
#       'description': '',
#       'format': 'CSV',
#       'hash': '',
#       'id': 'ce802191-452f-4455-9b31-19fe0dff11b1',
#       'last_modified': None,
#       'mimetype': 'text/csv',
#       'mimetype_inner': None,
#       'name': 'Comma Separated Values File',
#       'no_real_name': 'True',
#       'package_id': '436a875e-9440-4c6f-8b13-c8deb71466d6',
#       'position': 2,
#       'qa': '{\'updated\': \'2017-11-19T12:04:47.726303\', \'openness_score\': 0, \'archival_timestamp\': \'2017-11-15T03:50:50.027815\', \'format\': None, \'created\': \'2017-11-19T12:04:47.731548\', \'resource_timestamp\': None, \'openness_score_reason\': u"File could not be downloaded. Reason: Download error. Error details: Error with the download: local variable \'saved_chunk\' referenced before assignment. Attempted on 15/11/2017. This was the first attempt."}',
#       'resource_type': None,
#       'revision_id': '9fca47f5-12ee-42a0-9761-0903adfe14af',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 21, 'total': 689},
#       'url': 'https://data.townofcary.org/api/v2/catalog/datasets/rdu-weather-history/exports/csv',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None}],
#     'revision_id': 'ccce32d2-1030-4725-80e2-f2dc12a3e7bc',
#     'state': 'active',
#     'tags': [{'display_name': 'rainfall',
#       'id': 'c35e4f8f-b187-4b87-b2ad-dc3b9c56c987',
#       'name': 'rainfall',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'temperature',
#       'id': '43703fee-ad58-4a94-aef7-4e903e93eb62',
#       'name': 'temperature',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'weather',
#       'id': '5018d3b3-3c20-4b18-84f6-e2e69ce8bd4e',
#       'name': 'weather',
#       'state': 'active',
#       'vocabulary_id': None}],
#     'title': 'Local Weather Archive',
#     'tracking_summary': {'recent': 89, 'total': 2977},
#     'type': 'dataset',
#     'url': None,
#     'version': None},
#    {'author': None,
#     'author_email': None,
#     'creator_user_id': '47303a9e-1187-4290-85a3-1fc02dc49e4a',
#     'extras': [{'key': 'harvest_source_id',
#       'value': '7d00a3ae-0bb4-4f51-82ec-6901c0a07f87'},
#      {'key': 'resource-type', 'value': 'Dataset'},
#      {'key': 'source_hash',
#       'value': 'c048e7fd9007cafea0a17b563fdd2b785cc846f7'},
#      {'key': 'accessLevel', 'value': 'public'},
#      {'key': 'temporal', 'value': '1975-01-01/2018-01-01'},
#      {'key': 'theme', 'value': ['transportation']},
#      {'key': 'catalog_conformsTo',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema'},
#      {'key': 'catalog_@context',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.jsonld'},
#      {'key': 'catalog_describedBy',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.json'},
#      {'key': 'harvest_source_title', 'value': 'OAR-OTAQ Non-Geo Records'},
#      {'key': 'source_schema_version', 'value': '1.1'},
#      {'key': 'programCode', 'value': ['020:033']},
#      {'key': 'bureauCode', 'value': ['020:00']},
#      {'key': 'landingPage', 'value': 'https://www.epa.gov/automotive-trends'},
#      {'key': 'harvest_object_id',
#       'value': '9a3fab50-b0e2-403d-a553-11060ea115ca'},
#      {'key': 'publisher',
#       'value': 'U.S. EPA Office of Air and Radiation (OAR) - Office of Transportation and Air Quality (OTAQ)'},
#      {'key': 'license', 'value': 'https://edg.epa.gov/EPA_Data_License.html'},
#      {'key': 'language', 'value': ['en-US']},
#      {'key': 'modified', 'value': '2019-03-01'},
#      {'key': 'source_datajson_identifier', 'value': True},
#      {'key': 'catalog_@id',
#       'value': 'https://edg.epa.gov/data/PUBLIC/OAR/OTAQ/metadata/OAR-OTAQ.json'},
#      {'key': 'accrualPeriodicity', 'value': 'R/P1Y'},
#      {'key': 'identifier', 'value': '743D3E4E-C636-11E6-9D9D-CEC0C932CE01'},
#      {'key': 'harvest_object_id',
#       'value': '9a3fab50-b0e2-403d-a553-11060ea115ca'},
#      {'key': 'harvest_source_id',
#       'value': '7d00a3ae-0bb4-4f51-82ec-6901c0a07f87'},
#      {'key': 'harvest_source_title', 'value': 'OAR-OTAQ Non-Geo Records'}],
#     'groups': [],
#     'id': '58e85842-ad7d-4cf3-8004-7261eebf3705',
#     'isopen': True,
#     'license_id': 'other-license-specified',
#     'license_title': 'Other License Specified',
#     'maintainer': 'Aaron Hula',
#     'maintainer_email': 'hula.aaron@epa.gov',
#     'metadata_created': '2018-09-24T16:09:29.050702',
#     'metadata_modified': '2019-04-17T21:22:34.163278',
#     'name': 'light-duty-automotive-technology-carbon-dioxide-emissions-and-fuel-economy-trends-data-5ff55',
#     'notes': "This annual report is part of the U.S. Environmental Protection Agency’s (EPA) commitment to provide the public with information about new light-duty vehicle greenhouse gas (GHG) emissions, fuel economy, technology data, and auto manufacturers' performance in meeting the agency’s GHG emissions standards. EPA has collected data on every new light-duty vehicle model sold in the United States since 1975, either from testing performed by EPA at the National Vehicle and Fuel Emissions Laboratory in Ann Arbor, Michigan, or directly from manufacturers using official EPA test procedures. These data are collected to support several important national programs, including EPA criteria pollutant and GHG standards, the U.S. Department of Transportation’s National Highway Traffic Safety Administration (NHTSA) Corporate Average Fuel Economy (CAFE) standards, and vehicle Fuel Economy and Environment labels. The downloadable data are available in the report PDF or spreadsheet (XLS) formats.",
#     'num_resources': 1,
#     'num_tags': 44,
#     'organization': {'approval_status': 'approved',
#      'created': '2013-03-14T03:44:48.513616',
#      'description': 'Our mission is to protect human health and the environment. ',
#      'id': '6d90e48d-3076-4327-b2f4-c33919f374d5',
# ...
#       'mimetype_inner': None,
#       'name': 'JSON File',
#       'no_real_name': 'True',
#       'package_id': '3796df99-d11e-4cd2-8d6f-fe031a03e803',
#       'position': 0,
#       'qa': '{\'updated\': \'2017-11-22T18:05:31.604911\', \'openness_score\': 3, \'archival_timestamp\': \'2017-11-22T18:03:59.937973\', \'format\': u\'JSON\', \'created\': \'2017-11-22T18:05:31.612340\', \'resource_timestamp\': None, \'openness_score_reason\': u\'Could not determine a file extension in the URL. Format field "JSON" receives score: 3.\'}',
#       'resource_type': None,
#       'revision_id': '3e20b38f-11dc-46d5-8226-a918743bdc43',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 11, 'total': 51},
#       'url': 'https://www.chapelhillopendata.org/api/v2/catalog/datasets/census-diversity',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None},
#      {'archiver': "{'is_broken_printable': 'Downloaded OK', 'updated': '2017-11-22T18:04:00.312237', 'cache_filepath': u'None', 'last_success': '2017-11-22T18:04:00.312237', 'size': u'3', 'is_broken': False, 'failure_count': 0, 'etag': None, 'status': 'Archived successfully', 'url_redirected_to': None, 'hash': u'None', 'status_id': 0, 'reason': u'', 'last_modified': None, 'resource_timestamp': '2017-11-20T13:41:29.826615', 'mimetype': u'application/json', 'cache_url': u'None', 'created': '2017-11-22T18:04:00.328779', 'first_failure': None}",
#       'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2017-11-20T13:41:29.986328',
#       'description': '',
#       'format': 'JSON',
#       'hash': '',
#       'id': '7c99fed8-90d1-43cd-bc2c-67ed0f9331f8',
#       'last_modified': None,
#       'mimetype': 'application/json',
#       'mimetype_inner': None,
#       'name': 'JSON File',
#       'no_real_name': 'True',
#       'package_id': '3796df99-d11e-4cd2-8d6f-fe031a03e803',
#       'position': 1,
#       'qa': '{\'updated\': \'2017-11-22T18:05:31.628188\', \'openness_score\': 3, \'archival_timestamp\': \'2017-11-22T18:04:00.312237\', \'format\': u\'JSON\', \'created\': \'2017-11-22T18:05:31.636913\', \'resource_timestamp\': None, \'openness_score_reason\': u\'Could not determine a file extension in the URL. Format field "JSON" receives score: 3.\'}',
#       'resource_type': None,
#       'revision_id': '3e20b38f-11dc-46d5-8226-a918743bdc43',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 4, 'total': 34},
#       'url': 'https://www.chapelhillopendata.org/api/v2/catalog/datasets/census-diversity/exports/json',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None},
#      {'archiver': "{'is_broken_printable': 'Downloaded OK', 'updated': '2017-11-22T18:04:00.616964', 'cache_filepath': u'None', 'last_success': '2017-11-22T18:04:00.616964', 'size': u'3', 'is_broken': False, 'failure_count': 0, 'etag': None, 'status': 'Archived successfully', 'url_redirected_to': None, 'hash': u'None', 'status_id': 0, 'reason': u'', 'last_modified': None, 'resource_timestamp': '2017-11-20T13:41:29.826615', 'mimetype': u'text/csv', 'cache_url': u'None', 'created': '2017-11-22T18:04:00.643086', 'first_failure': None}",
#       'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2017-11-20T13:41:29.986332',
#       'description': '',
#       'format': 'CSV',
#       'hash': '',
#       'id': '02d71184-7c4b-49ed-9f67-c3fdd35dd05f',
#       'last_modified': None,
#       'mimetype': 'text/csv',
#       'mimetype_inner': None,
#       'name': 'Comma Separated Values File',
#       'no_real_name': 'True',
#       'package_id': '3796df99-d11e-4cd2-8d6f-fe031a03e803',
#       'position': 2,
#       'qa': '{\'updated\': \'2017-11-22T18:05:31.652704\', \'openness_score\': 3, \'archival_timestamp\': \'2017-11-22T18:04:00.616964\', \'format\': u\'CSV\', \'created\': \'2017-11-22T18:05:31.660232\', \'resource_timestamp\': None, \'openness_score_reason\': u\'Could not determine a file extension in the URL. Format field "CSV" receives score: 3.\'}',
#       'resource_type': None,
#       'revision_id': '3e20b38f-11dc-46d5-8226-a918743bdc43',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 18, 'total': 111},
#       'url': 'https://www.chapelhillopendata.org/api/v2/catalog/datasets/census-diversity/exports/csv',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None},
#      {'archiver': "{'is_broken_printable': 'Downloaded OK', 'updated': '2017-11-22T18:04:00.973565', 'cache_filepath': u'None', 'last_success': '2017-11-22T18:04:00.973565', 'size': u'3', 'is_broken': False, 'failure_count': 0, 'etag': None, 'status': 'Archived successfully', 'url_redirected_to': None, 'hash': u'None', 'status_id': 0, 'reason': u'', 'last_modified': None, 'resource_timestamp': '2017-11-20T13:41:29.826615', 'mimetype': u'application/zip', 'cache_url': u'None', 'created': '2017-11-22T18:04:00.990089', 'first_failure': None}",
#       'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2017-11-20T13:41:29.986335',
#       'description': '',
#       'format': 'SHP',
#       'hash': '',
#       'id': '4a65f103-cc86-4beb-86e8-b3ca7601d2ce',
#       'last_modified': None,
#       'mimetype': 'application/zip',
#       'mimetype_inner': None,
#       'name': 'Web Resource',
#       'no_real_name': 'True',
#       'package_id': '3796df99-d11e-4cd2-8d6f-fe031a03e803',
#       'position': 3,
#       'qa': '{\'updated\': \'2017-11-22T18:05:31.675612\', \'openness_score\': 2, \'archival_timestamp\': \'2017-11-22T18:04:00.973565\', \'format\': u\'SHP\', \'created\': \'2017-11-22T18:05:31.682663\', \'resource_timestamp\': None, \'openness_score_reason\': u\'Could not determine a file extension in the URL. Format field "SHP" receives score: 2.\'}',
#       'resource_type': None,
#       'revision_id': '3e20b38f-11dc-46d5-8226-a918743bdc43',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 4, 'total': 20},
#       'url': 'https://www.chapelhillopendata.org/api/v2/catalog/datasets/census-diversity/exports/shp',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None},
#      {'archiver': "{'is_broken_printable': 'Downloaded OK', 'updated': '2017-11-22T18:04:01.240408', 'cache_filepath': u'None', 'last_success': '2017-11-22T18:04:01.240408', 'size': u'3', 'is_broken': False, 'failure_count': 0, 'etag': None, 'status': 'Archived successfully', 'url_redirected_to': None, 'hash': u'None', 'status_id': 0, 'reason': u'', 'last_modified': None, 'resource_timestamp': '2017-11-20T13:41:29.826615', 'mimetype': u'application/json', 'cache_url': u'None', 'created': '2017-11-22T18:04:01.256822', 'first_failure': None}",
#       'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2017-11-20T13:41:29.986338',
#       'description': '',
#       'format': 'GeoJSON',
#       'hash': '',
#       'id': 'e0f23e2e-547d-4451-b610-842eeae910c6',
#       'last_modified': None,
#       'mimetype': 'application/json',
#       'mimetype_inner': None,
#       'name': 'Web Resource',
#       'no_real_name': 'True',
#       'package_id': '3796df99-d11e-4cd2-8d6f-fe031a03e803',
#       'position': 4,
#       'qa': '{\'updated\': \'2017-11-22T18:05:31.695236\', \'openness_score\': 3, \'archival_timestamp\': \'2017-11-22T18:04:01.240408\', \'format\': u\'GeoJSON\', \'created\': \'2017-11-22T18:05:31.701672\', \'resource_timestamp\': None, \'openness_score_reason\': u\'Could not determine a file extension in the URL. Format field "GeoJSON" receives score: 3.\'}',
#       'resource_type': None,
#       'revision_id': '3e20b38f-11dc-46d5-8226-a918743bdc43',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 2, 'total': 5},
#       'url': 'https://www.chapelhillopendata.org/api/v2/catalog/datasets/census-diversity/exports/geojson',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None}],
#     'revision_id': '3e20b38f-11dc-46d5-8226-a918743bdc43',
#     'state': 'active',
#     'tags': [{'display_name': 'census',
#       'id': '5f1554bc-7156-41cc-b06f-5f523c87ed97',
#       'name': 'census',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'demographics',
#       'id': '346daab9-6351-43a5-860d-4c96eccc8eb6',
#       'name': 'demographics',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'diversity',
#       'id': '53784367-a431-4ec7-b179-5913538ec6b2',
#       'name': 'diversity',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'ethnicity',
#       'id': 'bb53e753-ba10-4c8c-a4b2-0bd521cc48c2',
#       'name': 'ethnicity',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'gis',
#       'id': '3dc0c789-3e0c-4755-8418-1f1a0b82a70b',
#       'name': 'gis',
#       'state': 'active',
#       'vocabulary_id': None}],
#     'title': 'Diversity Index',
#     'tracking_summary': {'recent': 59, 'total': 672},
#     'type': 'dataset',
#     'url': None,
#     'version': None},
#    {'author': None,
#     'author_email': None,
#     'creator_user_id': '47303a9e-1187-4290-85a3-1fc02dc49e4a',
#     'extras': [{'key': 'publisher',
#       'value': 'Allegheny County / City of Pittsburgh / Western PA Regional Data Center'},
#      {'key': 'identifier', 'value': 'aea4a3fc-c45b-486b-a8e2-9d32bd5d986d'},
#      {'key': 'license',
#       'value': 'http://www.opendefinition.org/licenses/cc-zero'},
#      {'key': 'harvest_source_id',
#       'value': '041cd86b-18ea-412b-8d67-2ed1d6124bbf'},
#      {'key': 'catalog_@context',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.jsonld'},
#      {'key': 'resource-type', 'value': 'Dataset'},
#      {'key': 'modified', 'value': '2015-06-18T15:46:12.963937'},
#      {'key': 'harvest_source_title', 'value': 'WPRDC data.json'},
#      {'key': 'source_schema_version', 'value': '1.1'},
#      {'key': 'source_datajson_identifier', 'value': True},
#      {'key': 'theme', 'value': ['Civic Vitality & Governance', 'geospatial']},
#      {'key': 'metadata_type', 'value': 'geospatial'},
#      {'key': 'catalog_conformsTo',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema'},
#      {'key': 'accessLevel', 'value': 'public'},
#      {'key': 'harvest_object_id',
#       'value': '00c1da6a-8eaf-4a2d-8ffa-d982360ca182'},
#      {'key': 'source_hash',
#       'value': '29a7292a3fdd8521809365331e0a3d561b77ccd6'},
#      {'key': 'catalog_describedBy',
#       'value': 'https://project-open-data.cio.gov/v1.1/schema/catalog.json'},
#      {'key': 'harvest_object_id',
#       'value': '00c1da6a-8eaf-4a2d-8ffa-d982360ca182'},
#      {'key': 'harvest_source_id',
#       'value': '041cd86b-18ea-412b-8d67-2ed1d6124bbf'},
#      {'key': 'harvest_source_title', 'value': 'WPRDC data.json'}],
#     'groups': [{'description': 'Local Government Topic - for all datasets with state, local, county organizations',
#       'display_name': 'Local Government',
#       'id': 'ccc6c266-eee8-44bd-89aa-7cd8c4c6bf46',
#       'image_display_url': '',
#       'name': 'local',
#       'title': 'Local Government'}],
#     'id': 'f284e201-1a83-45e9-b37d-79cb236fbc4b',
#     'isopen': True,
#     'license_id': 'other-license-specified',
#     'license_title': 'Other License Specified',
#     'maintainer': 'Western Pennsylvania Regional Data Center',
#     'maintainer_email': 'wprdc@pitt.edu',
#     'metadata_created': '2016-06-21T03:44:36.787769',
#     'metadata_modified': '2016-06-28T02:29:35.503007',
#     'name': 'pittsburgh-city-council-district-map',
#     'notes': 'Boundaries for Pittsburgh City Council',
#     'num_resources': 1,
#     'num_tags': 4,
#     'organization': {'approval_status': 'approved',
#      'created': '2016-06-20T14:59:06.173417',
#      'description': 'Allegheny County (Pennsylvania) and the City of Pittsburgh both publish their data through the Western Pennsylvania Regional Data Center. The Western Pennsylvania Regional Data Center supports key community initiatives by making public information easier to find and use. The Data Center maintains Allegheny County and the City of Pittsburgh’s open data portal, and provides a number of services to data publishers and users. The Data Center also hosts datasets from these and other public sector agencies, academic institutions, and non-profit organizations. The Data Center is managed by the University of Pittsburgh’s Center for Social and Urban Research, and is a partnership of the University, Allegheny County and the City of Pittsburgh.',
#      'id': 'a7d30359-b403-426c-bc33-a1cf87d8e548',
#      'image_url': 'https://upload.wikimedia.org/wikipedia/commons/thumb/7/7d/Seal_of_Pennsylvania.svg/1200px-Seal_of_Pennsylvania.svg.png',
#      'is_organization': True,
#      'name': 'allegheny-county-city-of-pittsburgh-western-pa-regional-data-center',
#      'revision_id': '782736ff-3fc3-45d1-b2e6-9a86069d3c13',
#      'state': 'active',
#      'title': 'Allegheny County / City of Pittsburgh / Western PA Regional Data Center',
#      'type': 'organization'},
#     'owner_org': 'a7d30359-b403-426c-bc33-a1cf87d8e548',
#     'private': False,
#     'relationships_as_object': [],
#     'relationships_as_subject': [],
#     'resources': [{'archiver': '{\'is_broken_printable\': \'Downloaded OK\', \'updated\': \'2017-12-11T09:16:23.758445\', \'cache_filepath\': u\'None\', \'last_success\': \'2017-12-11T09:16:23.758445\', \'size\': u\'3\', \'is_broken\': False, \'failure_count\': 0, \'etag\': u\'W/"fe7060b2a3354fa815088461d35be3d4"\', \'status\': \'Archived successfully\', \'url_redirected_to\': None, \'hash\': u\'None\', \'status_id\': 0, \'reason\': u\'\', \'last_modified\': u\'Thu, 07 Dec 2017 04:32:15 GMT\', \'resource_timestamp\': \'2016-06-21T03:44:36.787769\', \'mimetype\': u\'text/html\', \'cache_url\': u\'None\', \'created\': \'2017-12-11T09:16:23.770796\', \'first_failure\': None}',
#       'cache_last_updated': None,
#       'cache_url': None,
#       'created': '2016-06-20T23:44:37.171727',
#       'description': '',
#       'format': 'HTML',
#       'hash': '',
#       'id': '0c7c26d6-6908-4e00-b429-b8a5a4868fae',
#       'last_modified': None,
#       'mimetype': 'text/html',
#       'mimetype_inner': None,
#       'name': 'Pittsburgh City Council District Map',
#       'package_id': 'f284e201-1a83-45e9-b37d-79cb236fbc4b',
#       'position': 0,
#       'qa': '{\'updated\': \'2017-12-13T00:55:43.088126\', \'openness_score\': 1, \'archival_timestamp\': \'2017-12-11T09:16:23.758445\', \'format\': u\'HTML\', \'created\': \'2017-12-13T00:53:01.141395\', \'resource_timestamp\': None, \'openness_score_reason\': u\'URL extension "html" relates to format "HTML" but a score for that format is not configured, so giving it default score 1.\'}',
#       'resource_type': None,
#       'revision_id': '0fde5f13-54f8-44a3-9906-280ac4b70b69',
#       'size': None,
#       'state': 'active',
#       'tracking_summary': {'recent': 18, 'total': 1375},
#       'url': 'https://pittsburghpa.maps.arcgis.com/apps/OnePane/basicviewer/index.html?appid=60e53861a0d949dcb2e6ada977de98d2',
#       'url_type': None,
#       'webstore_last_updated': None,
#       'webstore_url': None}],
#     'revision_id': '0fde5f13-54f8-44a3-9906-280ac4b70b69',
#     'state': 'active',
#     'tags': [{'display_name': 'city',
#       'id': 'a6c17c25-9685-4afe-90ae-428cd7b5c88d',
#       'name': 'city',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'council',
#       'id': '6e535d95-c99d-4517-bb11-bcde9c2ecbff',
#       'name': 'council',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'district',
#       'id': '173395db-6165-4848-afba-f4140dc7cea1',
#       'name': 'district',
#       'state': 'active',
#       'vocabulary_id': None},
#      {'display_name': 'map',
#       'id': '4b25baf2-c254-4949-8996-e9c3895fa2b6',
#       'name': 'map',
#       'state': 'active',
#       'vocabulary_id': None}],
#     'title': 'Pittsburgh City Council District Map',
#     'tracking_summary': {'recent': 58, 'total': 4381},
#     'type': 'dataset',
#     'url': None,
#     'version': None}],
#   'search_facets': {},
#   'sort': 'views_recent desc'},
#  'success': True}

# %%
data
# Out:
# {'help': 'https://demo.ckan.org/api/3/action/help_show?name=package_list',
#  'result': ['_-_-_',
#   '0-1-annual-probability-extents',
#   '0-1-annual-probability-extents-with-30-climate-change-adjustment',
#   '0-1-annual-probability-outputs',
#   '0-1-annual-probability-outputs-with-30-climate-change-adjustment',
#   '02a8c314-e726-44fb-88da-2e535e788675',
#   '02p-expenditure-over-25k-apr-19',
#   '02p-expenditure-over-25k-feb-20',
#   '02p-expenditure-over-25k-mar-19',
#   '02p-expenditure-over-25k-nov-19',
#   '02p-expenditure-over-25k-sep-19',
#   '09-listas',
#   '10019191949485756',
#   '100-filtered-whey-protein-isolate-canada',
#   '100-natural-fat-burner-to-reduce-calories-easily',
#   '1022330232',
#   '1080p-2020',
#   '10-incredible-fast-flow-male-enhancement-examples',
#   '10-shocking-facts-about-battery-warehouse',
#   '10-tips-for-silgenix-male-enhancement',
#   '10-unforgivable-sins-of-one-shot-keto',
#   '1-1',
#   '111',
#   '11111',
#   '111111111111111111111111111',
#   '111asdfasdf',
#   '112112',
#   '12121',
#   '121212',
#   '1213213',
#   '1231',
#   '123123123a-a-a',
#   '1231321',
#   '123321',
#   '1234567890-dani-pro-mistseznahodzhennya-gromadskogo-transportu--',
#   '1234567890-generalni-plani-naselenih-punktiv-istorikoarhit-',
#   '1234567890-osnovni-polozhennya-generalnogo-planu-ta-detalnih--',
#   '1234567890-reestr-naboriv-danih-scho-perebuvayut-u-volodinni-o-',
#   '123555555555555555555',
#   '123-hp-com-setup-guide-for-hp-printer-installation',
#   '123movies-hd-let-him-go-2020-watch-full-movie-online',
#   '123movies-watch-death-on-the-nile-2020-hd-full-movie-online',
#   '123movies-watch-let-him-go-2020-hd-full-movie-online',
#   '12f1e570-94ab-44e1-aef4-3b6cefb07363',
#   '12hourshift-fnp',
#   '12hourshift-gkc',
#   '12hourshift-iud',
#   '12hourshift-kcy',
#   '12hourshift-lgz',
#   '12hourshift-nbb',
#   '12hourshift-nqk',
#   '12hourshift-oli',
#   '12hourshift-oye',
#   '12hourshift-rag',
#   '12hourshift-rru',
#   '12hourshift-sxn',
#   '12hourshift-tec',
#   '12hourshift-ucr',
#   '12hourshift-zgx',
#   '13377x',
#   '134',
#   '16c9f67c-3c56-45e1-8b76-243419e7fba5',
#   '17x01-all-tomorrow-s-parties',
#   '18-consideracoes-finais',
#   '1aa641a7-3218-4fdc-8633-974f45dec85b',
#   '1bc6ad32-d39d-428c-8d03-9aca152a6f51',
#   '1c30e0b3-e7ac-4b77-aea7-69bdce5a1fab',
#   '1c6119ba-8277-4cde-8535-5f92f17fbc06',
#   '1goyang',
#   '1jpo2jrypzryphdfrcc6fzf-9yyixkaiu',
#   '1lih95grohlqqoeiezwxklycza1w2hpuc',
#   '1qmm8h3frrvgq2gsgwuhymqlawwzoxlqp',
#   '1rjifussywkbxtygnm14znchnzwckwahh',
#   '1ry5ffmtbxnf0gefyqq-c6om0jee9aajz',
#   '1st-event',
#   '1sy5nu90lhh8is6ida8pru2xtp3mpmyr4',
#   '1vuo8ofykuesjektl_anpcqgesnmjz7zx',
#   '2016-spanish-hospitals-with-paediatric-residence',
#   '2019-6',
#   '2019-kenya-census',
#   '2020',
#   '2020-nikah-ve-nisan-davetiye-modelleri',
#   '2067-bpa',
#   '2067-clt',
#   '2067-hxp',
#   '2067-iie',
#   '2067-iix',
#   '2067-jfk',
#   '2067-kcs',
#   '2067-qft',
#   '2067-qki',
#   '2067-sdr',
#   '2067-stc',
#   '2067-streaming-gratuit-de-films-kodi-smit-mcphee',
#   '2067-tbw',
#   '2067-ujr',
#   '2-1-32',
#   '21bridges-aoe',
#   '222',
#   '2257',
#   '250-logo-ckan',
#   '2561',
#   '2563',
#   '26j-spanish-general-elections',
#   '28ef643c-c776-468a-abc2-456c653bbab5',
#   '2c7cc0d9-1346-468b-94ba-4d246164e580',
#   '2hearts-ahj',
#   '2x01-chapter-9-the-marshal',
#   '30joursmax-bfq',
#   '30-jours-max-film-gratuit-complet-philippe-lacheau',
#   '311-requests',
#   '32malasanastreet-sll',
#   '32malasanastreet-taq',
#   '3434344',
#   '365das-soy',
#   '365das-tax',
#   '365das-wek',
#   '365das-wem',
#   '365days-ads',
#   '365days-jpk',
#   '365days-kwi',
#   '365days-lbx',
#   '365days-lfp',
#   '365days-lfw',
#   '365days-stg',
#   '365days-ttq',
#   '365days-udo',
#   '365days-uzo',
#   '365days-xbt',
#   '365days-ygm',
#   '365dias-uee',
#   '365dias-wnk',
#   '365giorni-nmi',
#   '365giorni-oxo',
#   '365jours-bzj',
#   '365jours-dcf',
#   '365jours-mho',
#   '365jours-mxa',
#   '365jours-rnx',
#   '365jours-uas',
#   '365jours-yqg',
#   '365jours-zua',
#   '365nap-qgs',
#   '365nap-tsw',
#   '39a48473-7054-4ee7-b09a-dc7af58aed29',
#   '3-reasons-why-wise-token-could-be-a-massive-winner-in-2021',
#   '3-ways-to-australian-citizenship',
#   '3x01-that-hope-is-you',
#   '40-best-ways-to-sell-diva-trim-keto',
#   '40-things-to-do-immediately-about-nurielle-cream',
#   '435',
#   '44d37669-79cd-473f-9d15-ea0701b8791f',
#   '460c9ffd-cfd2-4557-88d0-034d09e67e86',
#   '461-bsc',
#   '461daysofbentoapr-cbf',
#   '461daysofbentoapr-ebn',
#   '461daysofbentoapr-fih',
#   '461daysofbentoapr-gtw',
#   '461daysofbentoapr-oex',
#   '461daysofbentoapr-qsg',
#   '461daysofbentoapr-taz',
#   '461daysofbentoapr-tmz',
#   '461daysofbentoapr-wtf',
#   '461daysofbentoapr-xlw',
#   '461daysofbentoapr-ylh',
#   '461daysofbentoapr-zos',
#   '461-fhw',
#   '461-gew',
#   '461-ihb',
#   '461-jcy',
#   '461-rwc',
#   '461-umi',
#   '4ef2ed4f-bb66-4fe1-a7f1-e5954814f309',
#   '5258bde5-eee3-42ab-a26c-ad457401bba6',
#   '5446',
#   '555',
#   '5e4d6cf9373b6d940c5b188b',
#   '5e92f1dc-3ee0-4ab2-9c48-6c3dcfa79e7f',
#   '5-easy-steps-to-more-fast-flow-male-enhancement-sales',
#   '5fbe357e-3ea9-44ed-8323-8aaf1c9ec27e',
#   '5-stories-you-didn-t-know-about-max-ignite-keto',
#   '5-things-to-demystify-nulavance-united-kingdom',
#   '5-things-you-didn-t-know-about-divatrim-keto',
#   '5-things-you-must-know-about-loriax-united-kingdom',
#   '5-tips-to-reinvent-your-vialophin-male-enhancement-and-win',
#   '5-ways-cannaboost-wellness-cbd-will-help-you-get-more-business',
#   '5-ways-to-immediately-start-selling-domin-xt-male-enhancement',
#   '5-ways-virilitrex-male-enhancement-will-help-you-get-more-business',
#   '60000rows',
#   '6129b9c5-64fe-4867-bf87-67323f62b3e6',
#   '63b0b58c-0d3f-4c0b-ba92-b833de1b3e44',
#   '667a8311-8ba2-4c8f-9e02-3fc77d83ea3e',
#   '69a55f87-8ebc-47fc-90b7-ad630637c1ae',
#   '6a93220e-bab4-4358-a166-75089246580b',
#   '6adc96e6-b3ec-4de3-b1fb-c72bf53f9fcd',
#   '6bc397ef-001f-49a3-89e8-9d2c6026adcd',
#   '6ec5e01f-48cb-47c7-b8da-a0635e28562d',
#   '6-flow-3xl-male-enhancement-mistakes-that-will-cost-you-1m-over-the-next-10-years',
#   '6-strange-facts-about-early-vibe-cbd-oil',
#   '6-things-to-demystify-truvalast-south-africa',
#   '6-things-to-demystify-vyessence-skin-cream',
#   '6-things-you-have-in-common-with-t3-human-hemp-oil',
#   '6-ways-nulavance-south-africa-can-make-you-invincible',
#   '75',
#   '7542ce9b-7a2a-4207-a9c6-2e9e863d52b4',
#   '7e3a2fe2-43fd-4fc0-aa00-381a28828f47',
#   '7fe24d27-dd31-4f41-b200-8675c19fe54e',
#   '800-jyotish-baba-8875513486-muslim-totke-for-vashikaran-in-rajapalayam-tamil-nadu',
#   '819b9673-4892-4c11-a48e-4ab7154fd009',
#   '869104fd-0fe6-492d-a595-4c94ba0c6e27',
#   '8b80e26e-b4cb-4b1f-be8f-757170d05751',
#   '97be1be4-264d-46db-a4be-74115494254f',
#   '9802b80a-5cc9-49e4-a5f8-3fbf31e1f376',
#   '9807ca92-43e3-44c4-ad65-e7cf14be9911',
#   '99f89971-58a6-4f2a-b948-63f03f22c7ad',
#   '99test1234',
#   '9-competences-critiques-pour-bio-life-keto-france-remarquablement-bien',
#   '9-ways-to-control-herpes-virus-easily',
#   'a1auye1a-awppees-o1kovouou-iwavvns',
#   'a4e97afc-bdd5-4847-8844-ee6d65d628cc',
#   'a81bcad6-84f7-453e-9d57-214d33671cbb',
#   'aaa',
#   'aaa132',
#   'aaaaa',
#   'aaaaaaa',
#   'aaaaaaaaaaaaa',
#   'aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa',
#   'aaaaaaaaaaaaaaaaaaaasd',
#   'aaaasadasdasdasdas',
#   'aaaasd',
#   'aaaaw',
#   'aaabb',
#   'aaavas',
#   'aab',
#   'aabbccqaz',
#   'aaeiee-meaethtikon-epron',
#   'aasasdaasaasasasasd',
#   'aasdasds',
#   'aass',
#   'ababysittersguide-clj',
#   'ababysittersguide-rsj',
#   'a-babysitter-s-guide-to-monster-hunting-movie-free-online-to-watch-at-home-tamara-smart',
#   'abc123',
#   'abc3423424',
#   'abcdefg12345',
#   'abeautifuldayinth-cfa',
#   'about',
#   'about-canzana-cbd-hemp-oil',
#   'about-me',
#   'acalltospy-tre',
#   'a-cat-pic',
#   'acca3c56-a325-4fda-8e4f-27a580d49095',
#   'access-use-information',
#   'accident',
#   'accidentestrafico',
#   'accommodation-survey',
#   'accounts-payable',
#   'aces-of-canzana-cbd-drops',
#   'achicagoi7ektrgya-lcu',
#   'achicagoi7ektrgya-oow',
#   'acida-burn-reviews',
#   'acidaburn-reviews',
#   'acidaburn-reviewss',
#   'active-directory-users',
#   'actividades-de-ocio-y-cultura-madrid',
#   'actosanella',
#   'act-suburb-next-garbage-recycling-and-green-waste-collection-dates',
#   'acv-burn-australia-reviews-where-to-buy-scam-side-effects',
#   'acv-burn-united-kingdom',
#   'adadadadad',
#   'adam-dmg',
#   'adataset',
#   'a-dataset-test',
#   'a-dataset-test12',
#   'adawdad',
#   'additional-informati',
#   'additional-information-abou-the-data-type',
#   'adfadf',
#   'adfjdsiffsdkvhskjvksjvbsvkdfvkdfsnvsdfndvfd',
#   'adksaklfjaslfjskaljdasljkfsakjfsalkdjaklsjdaskjlfjsklajskflas',
#   'adl-population-density-by-region',
#   'adlsgen2',
#   'adlsgen2-1',
#   'adresse',
#   'advanced-keto-bhb-weight-let-it-melt',
#   'advancedketoplus',
#   'advantage-of-taking-keto-premiere-sverige-pills',
#   'advantages-and-disadvantages-of-magnum-xt-male-enhancement',
#   'advantages-of-keto-premiere',
#   'advantages-of-powervolt-energy-saver',
#   'advantages-of-reading-glasses-with-real-properfocus-glasses-lenses',
#   'advantages-of-slimymed-premium-slim-diet-pills',
#   'advantages-of-viaxal-enhance',
#   'adz77992-cuoly-com',
#   'ae-dataset',
#   'aefaf',
#   'a-e-i-o-u-n',
#   'aemet_stations',
#   'a-feral-world-movie-free-online-to-watch-at-home-caleb-liban',
#   'after2-kkp',
#   'after-chapitre-2-film-gratuit-complet',
#   'afterdepoisdaverd-bef',
#   'afterdepoisdaverd-wzo',
#   'afterenmilpedazos-dol',
#   'afterenmilpedazos-fpo',
#   'afterenmilpedazos-iyk',
#   'afterenmilpedazos-wox',
#   'afterlacollision-bip',
#   'afterlacollision-bnj',
#   'afterlacollision-fnd',
#   'afterlacollision-lic',
#   'afterlacollision-nbb',
#   'afterlacollision-nnn',
#   'afterlacollision-nuo',
#   'afterlacollision-rws',
#   'afterwecollided-aam',
#   'afterwecollided-aob',
#   'afterwecollided-ayq',
#   'afterwecollided-lic',
#   'after-we-collided-movie-free-online-to-watch-at-home-langford',
#   'afterwecollided-rme',
#   'afterwecollided-whd',
#   'afterwecollided-zqh',
#   'againonceagain-bfa',
#   'againonceagain-cbu',
#   'againonceagain-cma',
#   'againonceagain-ebc',
#   'againonceagain-egk',
#   'againonceagain-ewu',
#   'againonceagain-hii',
#   'againonceagain-ibr',
#   'againonceagain-jms',
#   'againonceagain-kad',
#   'againonceagain-lgz',
#   'againonceagain-lzx',
#   'againonceagain-mft',
#   'againonceagain-mmg',
#   'againonceagain-oox',
#   'againonceagain-pmw',
#   'againonceagain-rya',
#   'againonceagain-wkt',
#   'againonceagain-ynu',
#   'againonceagain-yug',
#   'agantestdata',
#   'ageless-glow-reviews',
#   'ageless-glow-reviewss',
#   'agility-fit-keto',
#   'agricultural-holdings-by-agricultural-area',
#   'agricultural-production-statistics',
#   'agriculture',
#   'agriculture-gdp',
#   'agrotoxicos-banidos-em-paises',
#   'ahovalpekszrnyter-dkp',
#   'ahovalpekszrnyter-zks',
#   'ah-resource-test-dataset',
#   'ailleurs-flk',
#   'ailleurs-gws',
#   'air-conditioner-service-in-adelaide',
#   'aircondition-test1',
#   'aircondition-test2',
#   'air-dataset',
#   'air-pollution-in-london',
#   'air-quality-madrid',
#   'air-quality-task',
#   'ajake-prabesa-karuna-in',
#   'ajjodattoi-qo1tntes',
#   'ajuntaments_5001_20000',
#   'akira-movie-free-online-to-watch-at-home-25th-anniversary-edition',
#   'akira-streaming-gratuit-de-films-mitsuo-iwata',
#   'akitaa',
#   'aklraj',
#   'aktiv-keto-take-care-of-your-body',
#   'akvo-foundation',
#   'alba-films-mon-grand-pere-et-moi-film-complet-streaming-vost-vf',
#   'alberto',
#   'alcaldes-de-puerto-rico',
#   'alfa',
#   'alireza-nouri',
#   'alive-zoa',
#   'alkemi',
#   'allmylife-mgk',
#   'alloy-steel-pipe-for-heater-exchanger',
#   'all-pokemon',
#   'all-you-need-to-know-about-192-168-1-254-ip-address',
#   'alojamientos-en-caceres',
#   'alone-mpx',
#   'along11111',
#   'alopecia-treatment-market-covid-19-impact-on-healthcare-industry-report',
#   'alpha-evolution-keto-canada-does-it-heap-you-get-more-fit-in-your-body',
#   'alpha-evolution-keto-canada-reviews-legit-keto-diet-pills',
#   'alpha-evolution-keto-outer-site-which-is-really-organization-which',
#   'alphafemmeketogenix',
#   'alpha-femme-ketogenix',
#   'alpha-femme-keto-genix-natural-metabolic-ketosis-support-formula',
#   'alpha-femme-keto-genix-reduce-fat-get-attractive-figure',
#   'alpha-visage-get-smooth-beautiful-skin',
#   'alpha-visage-reduce-wrinkles-and-lines',
#   'altai-balance-review',
#   'altas-de-bienes-muebles-cotai',
#   'alternate-fuel-station',
#   'alternatives-to-the-x-pro-drone',
#   'amanderleyhzasszo-ohh',
#   'amanderleyhzasszo-qny',
#   'amazin-brain-benefits',
#   'amazin-brain-how-to-use',
#   'amazin-brain-pills-it-is-100-safe-no-negative-result-read-more-more-info-from-here',
#   'amazinbrainpower',
#   'amazing-dataset',
#   'amazing-data-set',
#   'amazing-dataset1',
#   'amazing-discount-get-probiolite-for-the-lowest-price-here',
#   'amazon-aws-certified-solutions-architect-associate-saa-c02-exam',
#   'amber',
#   'ambient-air-quality-data-inventory',
#   'america-gdp',
#   'america-gdp-year',
#   'american-gdp',
#   'americanpieaprese-hpg',
#   'americanpieaprese-msz',
#   'americanpiepresen-cnp',
#   'americanpiepresen-eeu',
#   'americanpiepresen-fjw',
#   'americanpiepresen-fna',
#   'americanpiepresen-jne',
#   'americanpiepresen-kwp',
#   'americanpiepresen-lbs',
#   'americanpiepresen-lcx',
#   'americanpiepresen-mcu',
#   'americanpiepresen-nno',
#   'americanpiepresen-ogw',
#   'americanpiepresen-oxm',
#   'americanpiepresen-rch',
#   'americanpiepresen-rkq',
#   'americanpiepresen-sjo',
#   'americanpiepresen-tmc',
#   'americanpiepresen-tou',
#   'american-pie-presents-movie-free-online-to-watch-at-home-girls-rules',
#   'americanpiepresen-ucx',
#   'americanpiepresen-ynz',
#   'americanpiepresen-zoz',
#   'americanpieprsent-alu',
#   'americanpieprsent-ani',
#   'americanpieprsent-brz',
#   'americanpieprsent-cry',
#   'americanpieprsent-pmy',
#   'americanpieprsent-way',
#   'americanpieprsent-ylx',
#   'americanpieprsent-zca',
#   'amostviolentyear-pzm',
#   'andrasidan-yrg',
#   'androxene',
#   'androxene-may-improve-physical-perfomance',
#   'an-example-api',
#   'animal1',
#   'aniplex-demon-slayer-le-train-de-l-infini-film-complet-streaming-vost-vf',
#   'annefrankparallel-mfk',
#   'anofficerandaspy-rqj',
#   'anofficerandaspy-sjd',
#   'another-cool-ds',
#   'anotherround-mie',
#   'anotherround-mzu',
#   'another-test-dataset',
#   'another-test-remote-ckan-dataset',
#   'antebellum-cth',
#   'antiviral-drugs-market-global-covid-19-impact-industry-analysis-2020',
#   'antoub-test-dataset-001',
#   'antrum-bke',
#   'antrum-dln',
#   'antrum-fqb',
#   'antrum-gir',
#   'antrum-gjw',
#   'antrum-hee',
#   'antrum-hek',
#   'antrum-iiq',
#   'antrum-jrb',
#   'antrumofilmemaism-xzy',
#   'antrumofilmemaism-yqz',
#   'antrum-wju',
#   'antrum-wnp',
#   'antrum-xzq',
#   'antrum-ysu',
#   'antrum-zry',
#   'antrum-zug',
#   'anymore-9gowxbrml',
#   'anymore-gcoynfq-_',
#   'aopeee-aiayreia-nateo',
#   'aopeee-aiayreia-oeoaopoe-ttattaaottoyaoe',
#   'aopeee-aiayreia-reopria-tzeaetth',
#   'aparcamiento-publicos-de-malaga-de-ocupacion',
#   'aparcamientos',
#   'aparcamientos-de-malaga',
#   'aparcamientos-de-movilidad-reducida',
#   'aparcamientos-movilidad-reducida',
#   'aparcamientos-publicos-de-malaga-estado-de-ocupacion',
#   'api-data-test',
#   'api-test',
#   'apofoitoi',
#   'apostas-loterias',
#   'app-developers-adelaide',
#   'app-developers-toronto',
#   'app-development-california',
#   'apples_and_oranges',
#   'appointments',
#   'apprendistapap-bua',
#   'apprendistapap-pln',
#   'apprentipapa-brt',
#   'apprentipapa-djb',
#   'apprentipapa-gdm',
#   'apprentipapa-gmw',
#   'apprentipapa-has',
#   'apprentipapa-jna',
#   'apprentipapa-nza',
#   'apprentipapa-qxn',
#   'apprentipapa-rop',
#   'apprentipapa-sci',
#   'apprentipapa-uiu',
#   'apprentipapa-uqd',
#   'approaching-keto-body-tone-advanced-weight-loss-search-terms',
#   'aprilflowers-lre',
#   'aquietplaceii-ail',
#   'aquietplaceii-qan',
#   'aquietplacepartii-mzf',
#   'ara',
#   'aragon',
#   'arbeid',
#   'archive-free-online-to-watch-at-home-stacy-martin',
#   'arctic-datasets',
#   'are-banner-ads-worth',
#   'aree-percorse-dal-fuoco-2017',
#   'are-the-probiolite-benefits-real',
#   'are-there-any-keto-body-trim-side-effects',
#   'are-there-any-peace-cbd-oil-side-effects',
#   'are-there-any-side-effects-of-organixx-collagen-supplement',
#   'are-there-green-ape-cbd-gummies-side-effects',
#   'are-there-keto-body-trim-side-effects',
#   'are-there-keto-premiere-united-kingdom-side-effects',
#   'are-there-malepower-plus-male-enhancement-side-effects',
#   'are-there-mighty-leaf-cbd-oil-side-effects',
#   'are-there-mystic-ventures-cbd-cbd-side-effects',
#   'are-there-optima-keto-side-effects',
#   'are-there-prime-green-cbdts-cbd-side-effects',
#   'are-there-resultz-boost-male-enhancement-side-effects',
#   'are-there-resultz-boost-male-enhancement-side-effects-what-is-resultz-boost-made-of',
#   'are-there-spartan-man-testo-boost-pro-male-enhancement-side-effects',
#   'arkansas-ceo',
#   'arkansas-cto',
#   'arkansas-ddb',
#   'arkansas-els',
#   'arkansas-free-online-to-watch-at-home-liam-hemsworth',
#   'arkansas-gef',
#   'arkansas-hre',
#   'arkansas-ift',
#   'arkansas-kit',
#   'arkansas-ltt',
#   'arkansas-nso',
#   'arkansas-shl',
#   'arkansas-xfl',
#   'arkansas-xgq',
#   'aroparktest',
#   'arrondissement',
#   'asalsdjalid_1594384680',
#   'asalsdjalid_1594384689',
#   'asalsdjalid_1594384696',
#   'asalsdjalid_1594385114',
#   'ascrpcb',
#   'asd',
#   'asd2122dasdasdas',
#   'asdaccxzx',
#   'asdasd121212',
#   'asdasdadsa',
#   'asdasdasd',
#   'asdasdasd2213123',
#   'asdasdasd2321124141',
#   'asdasdasdadadas',
#   'asdasdasdasd',
#   'asdasdasdasd1234qswdcac2v1111',
#   'asdasdasdasdasd',
#   'asdasdasdasdasd-a',
#   'asdasdasdkjkkuiiiiujgvbn',
#   'asddsa',
#   'asdf23',
#   'asdfasdfasdfasdfasdf',
#   'asdfasdfasdfasdftests-set',
#   'asdffd',
#   'asdfg',
#   'asdfgh',
#   'asdfghjkl09',
#   'asdfghjkloiuytr',
#   'asdfsdf',
#   'asdsad',
#   'ashwagandhaplus-cbd-oil-reviews-uk-au-nz-ie-ca-clinically-tested',
#   'asocgava1',
#   'as-of-now-there-are-no-one-shot-keto-side-effects',
#   'aspengreencbdoil',
#   'assess-your-practice-with-palo-alto-networks-pse-strata-practice-test',
#   'assigs-jsq',
#   'assigs-uot',
#   'associacions',
#   'associacions12345',
#   'associacions3',
#   'associacions4556',
#   'associacions-gava-2021',
#   'asssss',
#   'astrology-courses-in-delhi',
#   'asus-service-centre-australia',
#   'atalho-para-portal',
#   'a-test-dataset',
#   'atm_da_nang',
#   'atm-t-i-da-n-ng',
#   'a-top-class-elite-mumbai-escorts-is-ready-to-serve-you',
#   'attooaeeie-yttoypreio-eeotepikon',
#   'attooaeeie-yttoypreio-eeotepikon-ahmhtphe',
#   'attooaeeie-yttoypreio-eeotepikon-thodoris',
#   'attooaeeie-yttoypreioy-eeotepikon',
#   'attoqaoe1s-uttoupyeiou-ecwtep1kwv',
#   'attoqaoe1s-yttee-2020',
#   'attoqaoe1s-yttoupyeiou-ecwtep1kwv-2020_ttattabao1jeiou-anuntpns',
#   'audit-2019-average-travel-time-to-nearest-hospital-by-public-transport-during-2031-am-peak',
#   'au-https-supplementsonlinestore-com-trim-fast-keto-au',
#   'automatic-wet-glue-labeling-machine-manufacturers',
#   'ava-had',
#   'a-very-country-christmas-homecoming',
#   'av-health-keto',
#   'av-health-keto-makes-you-slim-faster',
#   'avis-sur-keto-premiere-mise-a-jour-2020-supplement-perte-de-poids',
#   'awaze-uttar-pradesh-hindi-news',
#   'awpees-a1auye1a-anuntpns-ttattabao1jeiou',
#   'awpees-a1auye1a-apns-aauoujakns',
#   'awpees-a1auye1a-bao1jns-ttattayewpy1ou',
#   'awpees-a1auye1a-dimitris-seretis',
#   'awpees-a1auye1a-e1axou-ajecia',
#   'awpees-a1auye1a-eu0uuns-kato1attns',
#   'awpees-a1auye1a-kwvotavtiva-r1avvaka',
#   'awpees-a1auye1a-o1kovouou-iwavvns',
#   'awpees-a1auye1a-ovoua-ettwvuuo',
#   'awpees-atto-d1auye1a-na-po',
#   'aynamiko-tmhmaton-aiek-eeamhnoy-2018b',
#   'azure-health-keto',
#   'b3kat',
#   'b4ce4aaa-d504-4648-b3ae-f3b403fae11f',
#   'b8689d57-9efe-4799-b6e2-b966b4d6e301',
#   'b95740c6-1f83-4218-acf2-817cebfa3d39',
#   'ba-a-parda',
#   'babyteeth-zsz',
#   'backpack-0-1',
#   'badeducation-nhf',
#   'badevannskvalitet-uke-22-2019-sandefjord',
#   'bag-adressen-csv',
#   'bagger-bags',
#   'baixue',
#   'baixue1',
#   'baixue2',
#   'balita-ng-kalipay',
#   'bananadance',
#   'bananadance-dataset',
#   'bananadance-roilu4lzc',
#   'bananadance-uksmpofam',
#   'bananadance--xjnhrnll',
#   'bananatest',
#   'bank-account',
#   'bank-test',
#   'barrios',
#   'baseball-batting-data1',
#   'bassin_versant_topographique',
#   'batiment',
#   'bazz',
#   'bbbbbbbbbbbbb',
#   'beanpole-gxm',
#   'beanpole-ktb',
#   'bears',
#   'beauty8',
#   'bekreftet-koronasmitte-i-norge-per-fylke',
#   'bellalice',
#   'bend-oregon-weather-6-2020',
#   'benefits-kanajuice-cbd-oil',
#   'benefits-of-fast-fit-keto',
#   'benefits-of-keto-premiere',
#   'benefits-of-nulavance-skin-care-cream',
#   'benefits-of-powerpro-energy-saver-device',
#   'benefits-of-using-canzana-cbd-uk',
#   'benefits-of-using-keto-premiere-supplement',
#   'benefits-of-watt-pro-saver-appliances-to-save-light',
#   'benefits-you-get-from-trimtone-pills',
#   'bentest',
#   'bert-powell',
#   'besokende-stavanger-sentrum-2020-dag-for-dag',
#   'besokende-stavanger-sentrum-2020-mnd-for-mnd',
#   'besokende-stavanger-sentrum-korona',
#   'best-dumps-website',
#   'best-https-supplementsonlinestore-com-epic-keto',
#   'best-interior-designers-in-hyderabad',
#   'best-lunaire-keto-france-tips-you-will-read-this-year',
#   'best-marble-polishing-service',
#   'best-neet-preparation-app-dbmci',
#   'best-place-to-stay-in-manali',
#   'best-pomade-for-men',
#   'best-site-for-software',
#   'best-solution-of-heart-health-issues',
#   'best-study-material-test-see-guide',
#   'best-way-to-hire-it-telecom-technicians',
#   'bhm-779-public-financial-management-module-1',
#   'bicicletas-disponibles',
#   'bicycleshed',
#   'bid3',
#   'bid4',
#   'bidders',
#   'biden',
#   'bid-search2',
#   'bill',
#   'billtedfacethemus-elj',
#   'billy-joel-dftkpzf9o',
#   'bimal',
#   'bimdata',
#   'bimdataa',
#   'binodana-e-i-saptahe',
#   'binodana-skrina',
#   'biocompatibility-services-for-medical-devices',
#   'biogrowth-male-enhancement',
#   'biogrowth-reviews-pills',
#   'bioleptin',
#   'bioleptin-reviews',
#   'biolife-keto',
#   'biolife-keto-supplement-reviews',
#   'biosource-wellness-keto-pills',
#   'bioswitch-advanced-reviews',
#   'bio-switch-advanced-reviews-update-reviews-2020',
#   'bis',
#   'bitcoin-profit-erfahrungen-review',
#   'bjbm',
#   'blabla',
#   'blackbird-jif',
#   'black-latte-reviews',
#   'blah',
#   'blah-blah-blah',
#   'blarblar',
#   'blaskdkadk',
#   'blissful-cbd-oil-15-off-2-days-only',
#   'blood-balance-advanced-formula',
#   'blood-balance-advanced-formula-benefits',
#   'blood-balance-advanced-formula-benefits-blood-balance-advanced-formula-reviews',
#   'blood-balance-advanced-formula-blood-balance-for-diabetes-formula-is-it-true-order-today',
#   'blood-balance-advanced-formula-pills-ingredients',
#   'blood-flow-accelerator',
#   'blood-pressure-911-reviews',
#   'blood-sugar-blaster-reviews',
#   'blood-sugar-blaster-reviewss',
#   'blualix-male-enhancement',
#   'blubi-die-waldfee',
#   'bnm-base-rate',
#   'bnm-base-rate-bkkbmykl',
#   'bnm-base-rate-cibbmykl',
#   'bnm-base-rate-citimykl',
#   'bnm-base-rate-hbmbmykl',
#   'bnm-base-rate-hlbbmykl',
#   'bnm-base-rate-icbkmykl',
#   'body-corporate-cleaning-melbourne',
#   'body-massage-centre-in-coimbatore',
#   'boligpriser',
#   'boncat',
#   'bone-graft-substitutes-market-2020-covid-19-impact-analysis-report',
#   'bopp-tapes-reivews-what-is-bopp-tapes',
#   'borrar',
#   'boston_house',
#   'boszorknyok-qgq',
#   'boszorknyok-yki',
#   'bowel-guard-reviews',
#   'boysplatonic-eqm',
#   'boysplatonic-eyz',
#   'bp-zone-full-reviews-amazing-result-of-using-zenith-labs-bp-zone-price',
#   'bpzonereviews',
#   'brand-design-company-uae',
#   'brandweer-teams-vrnhn',
#   'brazilian-legis',
#   'breaking-surface-movie-free-online-to-watch-at-home-moa-gammel',
#   'breakthesilenceth-isr',
#   'breakthesilenceth-xeo',
#   'brief-overview-of-granite-male-enhancement-pills',
#   'brilliance-sf-cream',
#   'broil-zjw',
#   'broken-feet-2019',
#   'bruce-willis-hard-kill-streaming-complet-en-francais',
#   'brutal-force-reviews-why-choose-brutal-force-over-the-competitors',
#   'brutosprueba',
#   'bryan-baeumler-cbd-oil',
#   'bryan-farrell',
#   'bsb_2020',
#   'bsuos-test',
#   'budget',
#   'building-videos-to-answer-your-markets-questions',
#   'bulent9',
#   'bus2',
#   'business-analytics-software',
#   'business-coach-in-india-uma-mansharamani',
#   'buy-ambien-online-no-prescription-needed-uswebmeds',
#   'buy-ativan-online-no-prescription-needed-uswebmeds',
#   'buy-butalbital-online-no-prescription-needed-uswebmeds',
#   'buycanzanacbdoil',
#   'buy-carisoprodol-online-no-prescription-needed-uswebmeds',
#   'buy-carisoprodol-online-no-rx-required-tramadolmedication',
#   'buyciagramaleenhancement',
#   'buy-contact-lenses-online',
#   'buy-fioricet-online-no-prescription-needed-uswebmeds',
#   'buy-https-supplementsonlinestore-com-annabiol-cbd-oil-fr',
#   'buy-https-supplementsonlinestore-com-derma-corret-canada',
#   'buy-now-https-supplementsonlinestore-com-ultra-thermo-keto-uk',
#   'buy-soma-online-no-prescription-required-uswebmeds',
#   'buy-tramadol-online-no-prescription-needed',
#   'buy-tramadol-online-no-rx-needed-uswebmeds',
#   'buy-valium-online-no-prescription-required-uswebmeds',
#   'buy-xanax-online-no-prescription-needed',
#   'byebyemorons-pgs',
#   'byebyemorons-yab',
#   'by-what-method-should-magnum-xt-male-enhancement-be-taken',
#   'by-ybage89-via-p2p-idonate-com',
#   'c849907c-bb1b-4762-a54c-9033974a6637',
#   'c8fb11bf-28c3-4b04-b889-c1caa0418665',
#   'cagefighterworlds-dly',
#   'calidad-de-aire-de-malaga',
#   'call-girls-in-aerocity',
#   'cameotest',
#   'can-a-cbd-elixir-improve-your-health',
#   'canalisation',
#   'cancel-order',
#   'can-i-put-cream-after-moisturizer',
#   'canli-tv-izle',
#   'cannaleafz-cbd-oil-review-benefits-ingredients-where-to-buy',
#   'canzana',
#   'canzana-canzana-cbd-oil-reviews-cost-and-what-are-the-good-effects',
#   'canzana-cbd-hemp-oil',
#   'canzana-cbd-male-formula-uk',
#   'canzanacbdoil',
#   'canzana-cbd-oil',
#   'canzanacbd-oil',
#   'canzana-cbd-oil-anxiety-pain-and-relief-from-stress',
#   'canzana-cbd-oil-canzana-cbd-hemp-oil-shocking-reviews-benefits-price-buy-now',
#   'canzana-cbd-oil-check-price-reviews',
#   'canzana-cbd-oil-health-benefits-remove-stress-and-anxiety',
#   'canzana-cbd-oil-hemp-oil-reviews-before-read-ingredients-price-benefits-and-offer',
#   'canzana-cbd-oil-in-uk',
#   'canzana-cbd-oil-really-work',
#   'canzana-cbd-oil-review',
#   'canzana-cbd-oil-reviews-is-it-scam-or-legit-does-it-work',
#   'canzana-cbd-oil-scam-or-legit-work-benefits-cost-buy',
#   'canzanacbdoiluk',
#   'canzana-cbd-oil-uk',
#   'canzana-cbd-oil-uk-canzana-cbd-oil',
#   'canzana-cbd-oil-uk-review',
#   'canzana-cbd-oil-uk-review-uk',
#   'canzana-cbd-oil-uk-r-read-review-free-trial-benefits-price-huge-discount',
#   'canzana-cbd-oil-uk-uk',
#   'canzana-cbd-oil-where-to-get-it-trials-in-the-uk',
#   'canzana-cbd-oil-you-can-get-all-the-health-benefits',
#   'canzana-cbd-uk-canzana-cbd-oil-uk-5-facts-about-canzana-cbd-reviews',
#   'canzana-cbd-uk-review-how-does-canzana-cbd-work-or-scam',
#   'capitals-csv',
#   'capone-myl',
#   'captivestate-mlq',
#   'car',
#   'cara-membuat-halaman-uji-coba',
#   'caravan-towing-mirrors',
#   'cardio-clear-7-reviews',
#   'caribbean-marine-protected-area-management-campam-network-and-forum-mpa-regional-database',
#   'carpetas-de-investigacion-de-la-fgj-demo',
#   'carpet-cleaners-adelaide',
#   'cartografia-donana',
#   'casos_decesos',
#   'castles',
#   'catalogtest',
#   'cat-litter-no-dust-price',
#   'cats-around-the-world',
#   'cats-dogs-3-movie-free-online-to-watch-at-home-paws-unite',
#   'catsdogs3pawsunit-hfc',
#   'catsdogs3pawsunit-irw',
#   'catsdogs3pawsunit-mei',
#   'catsdogs3pawsunit-qir',
#   'catsdogs3pawsunit-tdb',
#   'catsdogs3pawsunit-tpx',
#   'catsdogs3pawsunit-zhc',
#   'cbdimmunityoil',
#   'cbd-oil-uk-canzana-cbd-oil-price-for-sale-official-100-natural-ingredients',
#   'cbu_cbu00020191114000000_20191121193627',
#   'cdf5f85e-242b-4ed9-bebd-5452ccffc68f',
#   'cedula-presupuestaria-de-gastos-2014',
#   'cedula-presupuestaria-de-gastos-2015',
#   'cedula-presupuestaria-de-ingresos-2015',
#   'cellxrenewal-reviews',
#   'censo-demografico-2000',
#   'centros-doncentes-salamanca',
#   'cereal-for-lunch',
#   'certificados-eficiencia-energetica-salamanca',
#   'cetic-sensors-dataset',
#   'channels',
#   'charles-williams-clear-vision-igenics-eye-supplement',
#   'chart-of-movies',
#   'cheerleaderabduct-exx',
#   'chef',
#   'chelseahandlerevo-weg',
#   'chemical-bleaching-agents-are-oftentimes-promoted',
#   'chiaki-t-test',
#   'child-dataset-one',
#   'childrenofthesea-obp',
#   'childrenofthesea-zso',
#   'china-data-cable-casing-machinery-manufacturers',
#   'chlorella-supplement-canada',
#   'chloro',
#   'choice-you-may-earn-an-entire',
#   'chrisandrew',
#   'chrissy-metz-weight',
#   'christin',
#   'christmas-on-the-range',
#   'christmas-tree-lane',
#   'ciagenix-france',
#   'ciagenix-male-enhancement',
#   'ciagra-male-enhancement',
#   'ciagra-male-enhancement-100-powerful-ciagra-pills-reviews-scam',
#   'cialix-male-enhancement',
#   'cialix-male-enhancement-shark-tank-reviews-this-pills-comes-on-top-10-list-in-the-world-how-to-buy',
#   'cias-abertas',
#   'cijeli-film-posle-sudara-2020-ceo-film-sa-prevodom-na-hrvatski-ii-srbija',
#   'cilirthjkgf',
#   'cimetiere',
#   'circula-bp-reviews',
#   'cisco-firewall-specialist-certification',
#   'citroburn-review',
#   'citroburn-review-2020-offer',
#   'citroburn-reviews-simple-promise',
#   'civity',
#   'ciytjhkjed',
#   'ck',
#   'ckan-chart-via-himalaya-com',
#   'ckan_data_search_demo_with_metadata',
#   'ckan-example-dataset',
#   'ckan-publishing',
#   'ckanr_test_dataset',
#   'ckan_test',
#   'ckan-to-frictionless-conversion',
#   'clear-sound-911-reviews-phytage-labs',
#   'click-here-this-link-https-buddysupplement-com-granite-pills',
#   'click-here-to-buy-effuel-cars-fuel-saver-order',
#   'click-to-order-keto-premiere-diet-pills-in-your-country',
#   'cliente',
#   'climate-change-scientists',
#   'cnttesttest',
#   'co2-ppm-mbd2020',
#   'co2-ppm-trends-in-atmospheric-carbon-dioxide',
#   'codeine-2018-jan',
#   'codii',
#   'codiii',
#   'codpays',
#   'coe',
#   'cog',
#   'coldblood-uoh',
#   'coldblood-uzt',
#   'collection-prueba',
#   'collectivite_territoriale',
#   'colored-heat-shrink-sleeves-dee-five-shrink',
#   'color_matching',
#   'colossal-cbd-oil-now-even-more-affordable-to-buy',
#   'combatwombat-nto',
#   'comeandsee-qjx',
#   'comeandsee-spm',
#   'comics',
#   'commechiensetchat-cld',
#   'commechiensetchat-ffx',
#   'commechiensetchat-hoo',
#   'commechiensetchat-kmm',
#   'commechiensetchat-orx',
#   'commechiensetchat-ptb',
#   'commechiensetchat-rfe',
#   'commechiensetchat-rin',
#   'commechiensetchat-uwa',
#   'commechiensetchat-zmu',
#   'comment-fonctionne-vraiment-hemp-max-lab',
#   'comment-keto-premiere-brule-t-il-les-graisses-excessives',
#   'comment-prendre-l-huile-de-cbd-hemp-max-lab',
#   'comment-utiliser-male-power-plus-france-pour-desirer',
#   'commune',
#   'commune_associee_ou_deleguee',
#   'communes_limitrophes',
#   'commune-tabarka',
#   'comocesegatos3pel-emy',
#   'comocesegatos3pel-hcx',
#   'comoperrosygatosl-cfa',
#   'comoperrosygatosl-efe',
#   'comoperrosygatosl-ikc',
#   'comoperrosygatosl-kjh',
#   'complianceperformnace',
#   'compras-enero-2020',
#   'conata-lasdf-almd-fa-s',
#   'concerts',
#   'concreteplans-drw',
#   'condominium',
#   'confirmed-corona-registrations-per-municipality-in-rogaland-norway',
#   'conjunto-de-dado-teste',
#   'conjunto-de-datos',
#   'conjunto-de-precios',
#   'conner_test',
#   'consejosdeunacang-jai',
#   'consejosdeunacang-uhi',
#   'consider-academic-writer-to-pay-someone-to-do-assignment',
#   ...],
#  'success': True}

# %%
# JSON
import json

# some JSON:
x =  '{ "name":"John", "age":30, "city":"New York"}'

# parse x:
y = json.loads(x)

# the result is a Python dictionary:
print(y["age"])
# Out:
# 30
